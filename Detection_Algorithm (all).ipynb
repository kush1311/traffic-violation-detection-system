# %%
import boto3
import os

# %%
aws_access_key_id = 'api'
aws_secret_access_key = 'acc key2'
aws_region = 'ap-south-1'
bucket_name = 'bikewatch'

# %%
s3 = boto3.client('s3',
                  aws_access_key_id=aws_access_key_id,
                  aws_secret_access_key=aws_secret_access_key,
                  region_name=aws_region)

# %%
local_directory = 'downloaded_images'
os.makedirs(local_directory, exist_ok=True)

# %%
def download_images_from_s3():
    response = s3.list_objects_v2(Bucket=bucket_name)
    
    if 'Contents' in response:
        for obj in response['Contents']:
            file_name = obj['Key']
            local_file_path = os.path.join(local_directory, file_name)
            
            # Ensure local directory structure matches S3 key structure
            if not os.path.exists(os.path.dirname(local_file_path)):
                os.makedirs(os.path.dirname(local_file_path))
            
            s3.download_file(bucket_name, file_name, local_file_path)
            print(f'Downloaded {file_name} to {local_file_path}')
    else:
        print(f'No files found in bucket {bucket_name}')

# %%
download_images_from_s3()
# Out:
# Downloaded non_violation/1.jpeg to downloaded_images\non_violation/1.jpeg
# Downloaded non_violation/10 (1).jpg to downloaded_images\non_violation/10 (1).jpg
# Downloaded non_violation/10.jpg to downloaded_images\non_violation/10.jpg
# Downloaded non_violation/1047207-helmets-1.jpg to downloaded_images\non_violation/1047207-helmets-1.jpg
# Downloaded non_violation/1115.jpg to downloaded_images\non_violation/1115.jpg
# Downloaded non_violation/2 (1).jpg to downloaded_images\non_violation/2 (1).jpg
# Downloaded non_violation/2 (2).jpg to downloaded_images\non_violation/2 (2).jpg
# Downloaded non_violation/2.jpg to downloaded_images\non_violation/2.jpg
# Downloaded non_violation/2.png to downloaded_images\non_violation/2.png
# Downloaded non_violation/3 (1).jpg to downloaded_images\non_violation/3 (1).jpg
# Downloaded non_violation/3.jpeg to downloaded_images\non_violation/3.jpeg
# Downloaded non_violation/3.jpg to downloaded_images\non_violation/3.jpg
# Downloaded non_violation/4.jpg to downloaded_images\non_violation/4.jpg
# Downloaded non_violation/5.jpg to downloaded_images\non_violation/5.jpg
# Downloaded non_violation/5.png to downloaded_images\non_violation/5.png
# Downloaded non_violation/6.jpg to downloaded_images\non_violation/6.jpg
# Downloaded non_violation/6.png to downloaded_images\non_violation/6.png
# Downloaded non_violation/7.jpg to downloaded_images\non_violation/7.jpg
# Downloaded non_violation/7.png to downloaded_images\non_violation/7.png
# Downloaded non_violation/79590503.jpg to downloaded_images\non_violation/79590503.jpg
# Downloaded non_violation/8.jpeg to downloaded_images\non_violation/8.jpeg
# Downloaded non_violation/8.jpg to downloaded_images\non_violation/8.jpg
# Downloaded non_violation/9.jpg to downloaded_images\non_violation/9.jpg
# Downloaded non_violation/92076367.webp to downloaded_images\non_violation/92076367.webp
# Downloaded non_violation/Helmet.6 (1).jpg to downloaded_images\non_violation/Helmet.6 (1).jpg
# Downloaded non_violation/Helmet.8.jpg to downloaded_images\non_violation/Helmet.8.jpg
# Downloaded non_violation/Image_02_Vishal_Pal.jpg to downloaded_images\non_violation/Image_02_Vishal_Pal.jpg
# Downloaded non_violation/Image_03_Vishal_Pal.jpg to downloaded_images\non_violation/Image_03_Vishal_Pal.jpg
# Downloaded non_violation/Image_06_Vishal_Pal.jpg to downloaded_images\non_violation/Image_06_Vishal_Pal.jpg
# Downloaded non_violation/Image_08_Vishal_Pal.jpg to downloaded_images\non_violation/Image_08_Vishal_Pal.jpg
# Downloaded non_violation/b4.jpg to downloaded_images\non_violation/b4.jpg
# Downloaded non_violation/b5.jpg to downloaded_images\non_violation/b5.jpg
# Downloaded non_violation/b6.jpeg to downloaded_images\non_violation/b6.jpeg
# Downloaded non_violation/b7.avif to downloaded_images\non_violation/b7.avif
# Downloaded non_violation/bike.jpg to downloaded_images\non_violation/bike.jpg
# Downloaded non_violation/helmet.jpg to downloaded_images\non_violation/helmet.jpg
# Downloaded non_violation/helmet1.jpg to downloaded_images\non_violation/helmet1.jpg
# Downloaded non_violation/helmet10.jpg to downloaded_images\non_violation/helmet10.jpg
# Downloaded non_violation/helmet2.jpg to downloaded_images\non_violation/helmet2.jpg
# Downloaded non_violation/helmet3.jpg to downloaded_images\non_violation/helmet3.jpg
# Downloaded non_violation/helmet5.jpg to downloaded_images\non_violation/helmet5.jpg
# Downloaded non_violation/helmet7.jpg to downloaded_images\non_violation/helmet7.jpg
# Downloaded non_violation/images (10).jpg to downloaded_images\non_violation/images (10).jpg
# Downloaded non_violation/images (5).jpg to downloaded_images\non_violation/images (5).jpg
# Downloaded non_violation/images (6).jpg to downloaded_images\non_violation/images (6).jpg
# Downloaded non_violation/images (7).jpg to downloaded_images\non_violation/images (7).jpg
# Downloaded non_violation/n.jpeg to downloaded_images\non_violation/n.jpeg
# Downloaded non_violation/n4.jpeg to downloaded_images\non_violation/n4.jpeg
# Downloaded non_violation/nonviolation_10.jpg to downloaded_images\non_violation/nonviolation_10.jpg
# Downloaded non_violation/nonviolation_2.png to downloaded_images\non_violation/nonviolation_2.png
# Downloaded non_violation/nonviolation_3.jpg to downloaded_images\non_violation/nonviolation_3.jpg
# Downloaded non_violation/nonviolation_4.jpg to downloaded_images\non_violation/nonviolation_4.jpg
# Downloaded non_violation/nonviolation_5.jpg to downloaded_images\non_violation/nonviolation_5.jpg
# Downloaded non_violation/nonviolation_6.jpg to downloaded_images\non_violation/nonviolation_6.jpg
# Downloaded non_violation/nv1.jpeg to downloaded_images\non_violation/nv1.jpeg
# Downloaded non_violation/pillion-rider.jpg to downloaded_images\non_violation/pillion-rider.jpg
# Downloaded non_violation/s1.jpg to downloaded_images\non_violation/s1.jpg
# Downloaded non_violation/s2.jpg to downloaded_images\non_violation/s2.jpg
# Downloaded violation/100407182.webp to downloaded_images\violation/100407182.webp
# Downloaded violation/2.jpg to downloaded_images\violation/2.jpg
# Downloaded violation/3.jpg to downloaded_images\violation/3.jpg
# Downloaded violation/3.png to downloaded_images\violation/3.png
# Downloaded violation/3007806.JPG to downloaded_images\violation/3007806.JPG
# Downloaded violation/65826504.jpg to downloaded_images\violation/65826504.jpg
# Downloaded violation/7.jpg to downloaded_images\violation/7.jpg
# Downloaded violation/7.jpg.jpeg to downloaded_images\violation/7.jpg.jpeg
# Downloaded violation/8 (1).jpg to downloaded_images\violation/8 (1).jpg
# Downloaded violation/8.jpg to downloaded_images\violation/8.jpg
# Downloaded violation/8.jpg.jpeg to downloaded_images\violation/8.jpg.jpeg
# Downloaded violation/Image_03_Vishal_Pal.jpg to downloaded_images\violation/Image_03_Vishal_Pal.jpg
# Downloaded violation/Image_07_Vishal_Pal.jpg to downloaded_images\violation/Image_07_Vishal_Pal.jpg
# Downloaded violation/Image_09_Vishal_Pal.jpg to downloaded_images\violation/Image_09_Vishal_Pal.jpg
# Downloaded violation/Non helmet.1.jpg to downloaded_images\violation/Non helmet.1.jpg
# Downloaded violation/Non helmet.9.jpg to downloaded_images\violation/Non helmet.9.jpg
# Downloaded violation/boymg0f7zs1b1.jpg to downloaded_images\violation/boymg0f7zs1b1.jpg
# Downloaded violation/image 10.jpeg to downloaded_images\violation/image 10.jpeg
# Downloaded violation/image5.jpg to downloaded_images\violation/image5.jpg
# Downloaded violation/images (1).jpeg to downloaded_images\violation/images (1).jpeg
# Downloaded violation/images.jpeg to downloaded_images\violation/images.jpeg
# Downloaded violation/v10.jpg to downloaded_images\violation/v10.jpg
# Downloaded violation/v11.jpg to downloaded_images\violation/v11.jpg
# Downloaded violation/v12.jpg to downloaded_images\violation/v12.jpg
# Downloaded violation/v13.jpg to downloaded_images\violation/v13.jpg
# Downloaded violation/v14.jpg to downloaded_images\violation/v14.jpg
# Downloaded violation/v15.jpg to downloaded_images\violation/v15.jpg
# Downloaded violation/v16.jpg to downloaded_images\violation/v16.jpg
# Downloaded violation/v17.jpg to downloaded_images\violation/v17.jpg
# Downloaded violation/v3.jpeg to downloaded_images\violation/v3.jpeg
# Downloaded violation/v3.jpg to downloaded_images\violation/v3.jpg
# Downloaded violation/v4.jpg to downloaded_images\violation/v4.jpg
# Downloaded violation/v5.jpg to downloaded_images\violation/v5.jpg
# Downloaded violation/v6.jpg to downloaded_images\violation/v6.jpg
# Downloaded violation/v7.jpg to downloaded_images\violation/v7.jpg
# Downloaded violation/v8.jpg to downloaded_images\violation/v8.jpg
# Downloaded violation/v9.jpg to downloaded_images\violation/v9.jpg
# Downloaded violation/vio_4.jpg to downloaded_images\violation/vio_4.jpg
# Downloaded violation/violation5.jpg to downloaded_images\violation/violation5.jpg
# Downloaded violation/violation8.jpg to downloaded_images\violation/violation8.jpg
# Downloaded violation/violation_1.jpg to downloaded_images\violation/violation_1.jpg
# Downloaded violation/violation_2.jpg to downloaded_images\violation/violation_2.jpg
# Downloaded violation/violation_3.jpg to downloaded_images\violation/violation_3.jpg

# %%
pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt

# %%
pip install opencv-python

# %%
# !pip install torch torchvision torchaudio
# !pip install opencv-python

# %%
pip install matplotlib

# %%
import cv2
import os

image_directory = "downloaded_images"

# Print the image directory being used
print(f"Image directory: {image_directory}")

# Check if the directory exists
if not os.path.exists(image_directory):
    print(f"Directory does not exist: {image_directory}")
else:
    print(f"Directory exists: {image_directory}")

# List the contents of the directory
directory_contents = os.listdir(image_directory)
print(f"Contents of directory ({len(directory_contents)} items): {directory_contents}")

# Process each item in the directory
for entry in directory_contents:
    entry_path = os.path.join(image_directory, entry)
    
    # Check if it's a directory
    if os.path.isdir(entry_path):
        print(f"Processing directory: {entry_path}")
        
        # List files in the directory
        files_in_directory = os.listdir(entry_path)
        print(f"Files in directory ({len(files_in_directory)} items): {files_in_directory}")
        
        # Process each file in the directory
        for image_name in files_in_directory:
            image_path = os.path.join(entry_path, image_name)
            print(f"Processing image: {image_path}")

            try:
                # Read the image
                image = cv2.imread(image_path)
                if image is not None:
                    print(f"Image loaded successfully: {image_name}")
                else:
                    print(f"Failed to load image (cv2.imread returned None): {image_name}")
            except Exception as e:
                print(f"Error loading image {image_name}: {e}")
    else:
        print(f"Skipping non-directory: {entry}")
# Out:
# Image directory: downloaded_images
# Directory exists: downloaded_images
# Contents of directory (2 items): ['non_violation', 'violation']
# Processing directory: downloaded_images\non_violation
# Files in directory (58 items): ['1.jpeg', '10 (1).jpg', '10.jpg', '1047207-helmets-1.jpg', '1115.jpg', '2 (1).jpg', '2 (2).jpg', '2.jpg', '2.png', '3 (1).jpg', '3.jpeg', '3.jpg', '4.jpg', '5.jpg', '5.png', '6.jpg', '6.png', '7.jpg', '7.png', '79590503.jpg', '8.jpeg', '8.jpg', '9.jpg', '92076367.webp', 'b4.jpg', 'b5.jpg', 'b6.jpeg', 'b7.avif', 'bike.jpg', 'Helmet.6 (1).jpg', 'Helmet.8.jpg', 'helmet.jpg', 'helmet1.jpg', 'helmet10.jpg', 'helmet2.jpg', 'helmet3.jpg', 'helmet5.jpg', 'helmet7.jpg', 'images (10).jpg', 'images (5).jpg', 'images (6).jpg', 'images (7).jpg', 'Image_02_Vishal_Pal.jpg', 'Image_03_Vishal_Pal.jpg', 'Image_06_Vishal_Pal.jpg', 'Image_08_Vishal_Pal.jpg', 'n.jpeg', 'n4.jpeg', 'nonviolation_10.jpg', 'nonviolation_2.png', 'nonviolation_3.jpg', 'nonviolation_4.jpg', 'nonviolation_5.jpg', 'nonviolation_6.jpg', 'nv1.jpeg', 'pillion-rider.jpg', 's1.jpg', 's2.jpg']
# Processing image: downloaded_images\non_violation\1.jpeg
# Image loaded successfully: 1.jpeg
# Processing image: downloaded_images\non_violation\10 (1).jpg
# Image loaded successfully: 10 (1).jpg
# Processing image: downloaded_images\non_violation\10.jpg
# Image loaded successfully: 10.jpg
# Processing image: downloaded_images\non_violation\1047207-helmets-1.jpg
# Image loaded successfully: 1047207-helmets-1.jpg
# Processing image: downloaded_images\non_violation\1115.jpg
# Image loaded successfully: 1115.jpg
# Processing image: downloaded_images\non_violation\2 (1).jpg
# Image loaded successfully: 2 (1).jpg
# Processing image: downloaded_images\non_violation\2 (2).jpg
# Image loaded successfully: 2 (2).jpg
# Processing image: downloaded_images\non_violation\2.jpg
# Image loaded successfully: 2.jpg
# Processing image: downloaded_images\non_violation\2.png
# Image loaded successfully: 2.png
# Processing image: downloaded_images\non_violation\3 (1).jpg
# Image loaded successfully: 3 (1).jpg
# Processing image: downloaded_images\non_violation\3.jpeg
# Image loaded successfully: 3.jpeg
# Processing image: downloaded_images\non_violation\3.jpg
# Image loaded successfully: 3.jpg
# Processing image: downloaded_images\non_violation\4.jpg
# Image loaded successfully: 4.jpg
# Processing image: downloaded_images\non_violation\5.jpg
# Image loaded successfully: 5.jpg
# Processing image: downloaded_images\non_violation\5.png
# Image loaded successfully: 5.png
# Processing image: downloaded_images\non_violation\6.jpg
# Image loaded successfully: 6.jpg
# Processing image: downloaded_images\non_violation\6.png
# Image loaded successfully: 6.png
# Processing image: downloaded_images\non_violation\7.jpg
# Image loaded successfully: 7.jpg
# Processing image: downloaded_images\non_violation\7.png
# Image loaded successfully: 7.png
# Processing image: downloaded_images\non_violation\79590503.jpg
# Image loaded successfully: 79590503.jpg
# Processing image: downloaded_images\non_violation\8.jpeg
# Image loaded successfully: 8.jpeg
# Processing image: downloaded_images\non_violation\8.jpg
# Image loaded successfully: 8.jpg
# Processing image: downloaded_images\non_violation\9.jpg
# Image loaded successfully: 9.jpg
# Processing image: downloaded_images\non_violation\92076367.webp
# Image loaded successfully: 92076367.webp
# Processing image: downloaded_images\non_violation\b4.jpg
# Image loaded successfully: b4.jpg
# Processing image: downloaded_images\non_violation\b5.jpg
# Image loaded successfully: b5.jpg
# Processing image: downloaded_images\non_violation\b6.jpeg
# Image loaded successfully: b6.jpeg
# Processing image: downloaded_images\non_violation\b7.avif
# Failed to load image (cv2.imread returned None): b7.avif
# Processing image: downloaded_images\non_violation\bike.jpg
# Image loaded successfully: bike.jpg
# Processing image: downloaded_images\non_violation\Helmet.6 (1).jpg
# Image loaded successfully: Helmet.6 (1).jpg
# Processing image: downloaded_images\non_violation\Helmet.8.jpg
# Image loaded successfully: Helmet.8.jpg
# Processing image: downloaded_images\non_violation\helmet.jpg
# Image loaded successfully: helmet.jpg
# Processing image: downloaded_images\non_violation\helmet1.jpg
# Image loaded successfully: helmet1.jpg
# Processing image: downloaded_images\non_violation\helmet10.jpg
# Image loaded successfully: helmet10.jpg
# Processing image: downloaded_images\non_violation\helmet2.jpg
# Image loaded successfully: helmet2.jpg
# Processing image: downloaded_images\non_violation\helmet3.jpg
# Image loaded successfully: helmet3.jpg
# Processing image: downloaded_images\non_violation\helmet5.jpg
# Image loaded successfully: helmet5.jpg
# Processing image: downloaded_images\non_violation\helmet7.jpg
# Image loaded successfully: helmet7.jpg
# Processing image: downloaded_images\non_violation\images (10).jpg
# Image loaded successfully: images (10).jpg
# Processing image: downloaded_images\non_violation\images (5).jpg
# Image loaded successfully: images (5).jpg
# Processing image: downloaded_images\non_violation\images (6).jpg
# Image loaded successfully: images (6).jpg
# Processing image: downloaded_images\non_violation\images (7).jpg
# Image loaded successfully: images (7).jpg
# Processing image: downloaded_images\non_violation\Image_02_Vishal_Pal.jpg
# Image loaded successfully: Image_02_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_03_Vishal_Pal.jpg
# Image loaded successfully: Image_03_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_06_Vishal_Pal.jpg
# Image loaded successfully: Image_06_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_08_Vishal_Pal.jpg
# Image loaded successfully: Image_08_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\n.jpeg
# Image loaded successfully: n.jpeg
# Processing image: downloaded_images\non_violation\n4.jpeg
# Image loaded successfully: n4.jpeg
# Processing image: downloaded_images\non_violation\nonviolation_10.jpg
# Image loaded successfully: nonviolation_10.jpg
# Processing image: downloaded_images\non_violation\nonviolation_2.png
# Image loaded successfully: nonviolation_2.png
# Processing image: downloaded_images\non_violation\nonviolation_3.jpg
# Image loaded successfully: nonviolation_3.jpg
# Processing image: downloaded_images\non_violation\nonviolation_4.jpg
# Image loaded successfully: nonviolation_4.jpg
# Processing image: downloaded_images\non_violation\nonviolation_5.jpg
# Image loaded successfully: nonviolation_5.jpg
# Processing image: downloaded_images\non_violation\nonviolation_6.jpg
# Image loaded successfully: nonviolation_6.jpg
# Processing image: downloaded_images\non_violation\nv1.jpeg
# Image loaded successfully: nv1.jpeg
# Processing image: downloaded_images\non_violation\pillion-rider.jpg
# Image loaded successfully: pillion-rider.jpg
# Processing image: downloaded_images\non_violation\s1.jpg
# Image loaded successfully: s1.jpg
# Processing image: downloaded_images\non_violation\s2.jpg
# Image loaded successfully: s2.jpg
# Processing directory: downloaded_images\violation
# Files in directory (43 items): ['100407182.webp', '2.jpg', '3.jpg', '3.png', '3007806.JPG', '65826504.jpg', '7.jpg', '7.jpg.jpeg', '8 (1).jpg', '8.jpg', '8.jpg.jpeg', 'boymg0f7zs1b1.jpg', 'image 10.jpeg', 'image5.jpg', 'images (1).jpeg', 'images.jpeg', 'Image_03_Vishal_Pal.jpg', 'Image_07_Vishal_Pal.jpg', 'Image_09_Vishal_Pal.jpg', 'Non helmet.1.jpg', 'Non helmet.9.jpg', 'v10.jpg', 'v11.jpg', 'v12.jpg', 'v13.jpg', 'v14.jpg', 'v15.jpg', 'v16.jpg', 'v17.jpg', 'v3.jpeg', 'v3.jpg', 'v4.jpg', 'v5.jpg', 'v6.jpg', 'v7.jpg', 'v8.jpg', 'v9.jpg', 'violation5.jpg', 'violation8.jpg', 'violation_1.jpg', 'violation_2.jpg', 'violation_3.jpg', 'vio_4.jpg']
# Processing image: downloaded_images\violation\100407182.webp
# Image loaded successfully: 100407182.webp
# Processing image: downloaded_images\violation\2.jpg
# Image loaded successfully: 2.jpg
# Processing image: downloaded_images\violation\3.jpg
# Image loaded successfully: 3.jpg
# Processing image: downloaded_images\violation\3.png
# Image loaded successfully: 3.png
# Processing image: downloaded_images\violation\3007806.JPG
# Image loaded successfully: 3007806.JPG
# Processing image: downloaded_images\violation\65826504.jpg
# Image loaded successfully: 65826504.jpg
# Processing image: downloaded_images\violation\7.jpg
# Image loaded successfully: 7.jpg
# Processing image: downloaded_images\violation\7.jpg.jpeg
# Image loaded successfully: 7.jpg.jpeg
# Processing image: downloaded_images\violation\8 (1).jpg
# Image loaded successfully: 8 (1).jpg
# Processing image: downloaded_images\violation\8.jpg
# Image loaded successfully: 8.jpg
# Processing image: downloaded_images\violation\8.jpg.jpeg
# Image loaded successfully: 8.jpg.jpeg
# Processing image: downloaded_images\violation\boymg0f7zs1b1.jpg
# Image loaded successfully: boymg0f7zs1b1.jpg
# Processing image: downloaded_images\violation\image 10.jpeg
# Image loaded successfully: image 10.jpeg
# Processing image: downloaded_images\violation\image5.jpg
# Image loaded successfully: image5.jpg
# Processing image: downloaded_images\violation\images (1).jpeg
# Image loaded successfully: images (1).jpeg
# Processing image: downloaded_images\violation\images.jpeg
# Image loaded successfully: images.jpeg
# Processing image: downloaded_images\violation\Image_03_Vishal_Pal.jpg
# Image loaded successfully: Image_03_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Image_07_Vishal_Pal.jpg
# Failed to load image (cv2.imread returned None): Image_07_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Image_09_Vishal_Pal.jpg
# Image loaded successfully: Image_09_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Non helmet.1.jpg
# Image loaded successfully: Non helmet.1.jpg
# Processing image: downloaded_images\violation\Non helmet.9.jpg
# Image loaded successfully: Non helmet.9.jpg
# Processing image: downloaded_images\violation\v10.jpg
# Image loaded successfully: v10.jpg
# Processing image: downloaded_images\violation\v11.jpg
# Image loaded successfully: v11.jpg
# Processing image: downloaded_images\violation\v12.jpg
# Image loaded successfully: v12.jpg
# Processing image: downloaded_images\violation\v13.jpg
# Image loaded successfully: v13.jpg
# Processing image: downloaded_images\violation\v14.jpg
# Image loaded successfully: v14.jpg
# Processing image: downloaded_images\violation\v15.jpg
# Image loaded successfully: v15.jpg
# Processing image: downloaded_images\violation\v16.jpg
# Image loaded successfully: v16.jpg
# Processing image: downloaded_images\violation\v17.jpg
# Image loaded successfully: v17.jpg
# Processing image: downloaded_images\violation\v3.jpeg
# Image loaded successfully: v3.jpeg
# Processing image: downloaded_images\violation\v3.jpg
# Image loaded successfully: v3.jpg
# Processing image: downloaded_images\violation\v4.jpg
# Image loaded successfully: v4.jpg
# Processing image: downloaded_images\violation\v5.jpg
# Image loaded successfully: v5.jpg
# Processing image: downloaded_images\violation\v6.jpg
# Image loaded successfully: v6.jpg
# Processing image: downloaded_images\violation\v7.jpg
# Image loaded successfully: v7.jpg
# Processing image: downloaded_images\violation\v8.jpg
# Image loaded successfully: v8.jpg
# Processing image: downloaded_images\violation\v9.jpg
# Image loaded successfully: v9.jpg
# Processing image: downloaded_images\violation\violation5.jpg
# Image loaded successfully: violation5.jpg
# Processing image: downloaded_images\violation\violation8.jpg
# Image loaded successfully: violation8.jpg
# Processing image: downloaded_images\violation\violation_1.jpg
# Image loaded successfully: violation_1.jpg
# Processing image: downloaded_images\violation\violation_2.jpg
# Image loaded successfully: violation_2.jpg
# Processing image: downloaded_images\violation\violation_3.jpg
# Image loaded successfully: violation_3.jpg
# Processing image: downloaded_images\violation\vio_4.jpg
# Image loaded successfully: vio_4.jpg

# %%
# !pip install ultralytics

# %%
import ultralytics
import cv2
import os

# Load the YOLOv8 model
model = ultralytics.YOLO('yolov8n.pt')

# Define directories
image_directory = "downloaded_images"
output_directory = "output_images_mixed"
os.makedirs(output_directory, exist_ok=True)

# Print image directory being used
print(f"Image directory: {image_directory}")

# Check if the directory exists
if not os.path.exists(image_directory):
    print(f"Directory does not exist: {image_directory}")
    exit()

# List the contents of the directory
directory_contents = os.listdir(image_directory)
print(f"Contents of directory ({len(directory_contents)} items): {directory_contents}")

# Process each item in the directory
for entry in directory_contents:
    entry_path = os.path.join(image_directory, entry)
    
    # Check if it's a directory
    if os.path.isdir(entry_path):
        print(f"Processing directory: {entry_path}")
        
        # List files in the directory
        files_in_directory = os.listdir(entry_path)
        print(f"Files in directory ({len(files_in_directory)} items): {files_in_directory}")
        
        # Process each file in the directory
        for image_name in files_in_directory:
            image_path = os.path.join(entry_path, image_name)
            print(f"Processing image: {image_path}")

            try:
                # Read the image
                image = cv2.imread(image_path)
                if image is None:
                    print(f"Failed to load image (cv2.imread returned None): {image_name}")
                    continue
                
                # Perform inference
                results = model.predict(source=image_path)

                # Extract bounding boxes and labels
                boxes = results[0].boxes.xyxy.cpu().numpy()  # xyxy format
                classes = results[0].boxes.cls.cpu().numpy()  # class indices
                scores = results[0].boxes.conf.cpu().numpy()  # confidences
                labels = results[0].names

                # Process each detected object
                for box, cls in zip(boxes, classes):
                    x1, y1, x2, y2 = box
                    label = labels[int(cls)]
                    if label in ['bicycle', 'motorcycle']:
                        color = (0, 255, 0)  # Green for bikes
                    elif label == 'person':
                        color = (255, 0, 0)  # Red for people
                    else:
                        continue

                    cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
                    cv2.putText(image, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

                output_path = os.path.join(output_directory, image_name)
                cv2.imwrite(output_path, image)
                print(f"Saved detected image: {output_path}")

            except Exception as e:
                print(f"Error processing image {image_name}: {e}")

    else:
        print(f"Skipping non-directory: {entry}")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:01<00:00, 4.24MB/s]
# Image directory: downloaded_images
# Contents of directory (2 items): ['non_violation', 'violation']
# Processing directory: downloaded_images\non_violation
# Files in directory (58 items): ['1.jpeg', '10 (1).jpg', '10.jpg', '1047207-helmets-1.jpg', '1115.jpg', '2 (1).jpg', '2 (2).jpg', '2.jpg', '2.png', '3 (1).jpg', '3.jpeg', '3.jpg', '4.jpg', '5.jpg', '5.png', '6.jpg', '6.png', '7.jpg', '7.png', '79590503.jpg', '8.jpeg', '8.jpg', '9.jpg', '92076367.webp', 'b4.jpg', 'b5.jpg', 'b6.jpeg', 'b7.avif', 'bike.jpg', 'Helmet.6 (1).jpg', 'Helmet.8.jpg', 'helmet.jpg', 'helmet1.jpg', 'helmet10.jpg', 'helmet2.jpg', 'helmet3.jpg', 'helmet5.jpg', 'helmet7.jpg', 'images (10).jpg', 'images (5).jpg', 'images (6).jpg', 'images (7).jpg', 'Image_02_Vishal_Pal.jpg', 'Image_03_Vishal_Pal.jpg', 'Image_06_Vishal_Pal.jpg', 'Image_08_Vishal_Pal.jpg', 'n.jpeg', 'n4.jpeg', 'nonviolation_10.jpg', 'nonviolation_2.png', 'nonviolation_3.jpg', 'nonviolation_4.jpg', 'nonviolation_5.jpg', 'nonviolation_6.jpg', 'nv1.jpeg', 'pillion-rider.jpg', 's1.jpg', 's2.jpg']
# Processing image: downloaded_images\non_violation\1.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1.jpeg: 640x416 1 person, 1 motorcycle, 180.6ms
# Speed: 3.0ms preprocess, 180.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 416)
# Saved detected image: output_images_mixed\1.jpeg
# Processing image: downloaded_images\non_violation\10 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\10 (1).jpg: 416x640 2 persons, 1 motorcycle, 166.3ms
# Speed: 2.0ms preprocess, 166.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected image: output_images_mixed\10 (1).jpg
# Processing image: downloaded_images\non_violation\10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\10.jpg: 384x640 1 person, 1 car, 1 motorcycle, 150.5ms
# Speed: 3.0ms preprocess, 150.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\10.jpg
# Processing image: downloaded_images\non_violation\1047207-helmets-1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1047207-helmets-1.jpg: 384x640 2 persons, 1 motorcycle, 148.8ms
# Speed: 3.0ms preprocess, 148.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\1047207-helmets-1.jpg
# Processing image: downloaded_images\non_violation\1115.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1115.jpg: 416x640 2 persons, 1 motorcycle, 163.8ms
# Speed: 2.0ms preprocess, 163.8ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected image: output_images_mixed\1115.jpg
# Processing image: downloaded_images\non_violation\2 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2 (1).jpg: 512x640 2 persons, 1 car, 1 motorcycle, 218.4ms
# Speed: 2.9ms preprocess, 218.4ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected image: output_images_mixed\2 (1).jpg
# Processing image: downloaded_images\non_violation\2 (2).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2 (2).jpg: 640x480 2 persons, 1 motorcycle, 205.1ms
# Speed: 4.0ms preprocess, 205.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
# Saved detected image: output_images_mixed\2 (2).jpg
# Processing image: downloaded_images\non_violation\2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2.jpg: 480x640 1 person, 1 motorcycle, 186.0ms
# Speed: 3.0ms preprocess, 186.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\2.jpg
# Processing image: downloaded_images\non_violation\2.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2.png: 640x416 1 person, 1 motorcycle, 163.7ms
# Speed: 3.0ms preprocess, 163.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 416)
# Saved detected image: output_images_mixed\2.png
# Processing image: downloaded_images\non_violation\3 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3 (1).jpg: 384x640 5 persons, 1 motorcycle, 146.8ms
# Speed: 2.0ms preprocess, 146.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\3 (1).jpg
# Processing image: downloaded_images\non_violation\3.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3.jpeg: 384x640 3 persons, 1 motorcycle, 2 backpacks, 161.4ms
# Speed: 2.0ms preprocess, 161.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\3.jpeg
# Processing image: downloaded_images\non_violation\3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3.jpg: 384x640 1 person, 1 motorcycle, 145.6ms
# Speed: 2.0ms preprocess, 145.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\3.jpg
# Processing image: downloaded_images\non_violation\4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\4.jpg: 384x640 2 persons, 1 motorcycle, 147.7ms
# Speed: 2.0ms preprocess, 147.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\4.jpg
# Processing image: downloaded_images\non_violation\5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\5.jpg: 384x640 2 persons, 1 motorcycle, 147.9ms
# Speed: 2.0ms preprocess, 147.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\5.jpg
# Processing image: downloaded_images\non_violation\5.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\5.png: 448x640 3 persons, 1 car, 1 motorcycle, 174.6ms
# Speed: 4.0ms preprocess, 174.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\5.png
# Processing image: downloaded_images\non_violation\6.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\6.jpg: 384x640 3 persons, 1 motorcycle, 1 bus, 1 truck, 142.5ms
# Speed: 3.0ms preprocess, 142.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\6.jpg
# Processing image: downloaded_images\non_violation\6.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\6.png: 576x640 2 persons, 1 motorcycle, 218.9ms
# Speed: 4.2ms preprocess, 218.9ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 640)
# Saved detected image: output_images_mixed\6.png
# Processing image: downloaded_images\non_violation\7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\7.jpg: 384x640 2 persons, 1 motorcycle, 164.6ms
# Speed: 3.0ms preprocess, 164.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\7.jpg
# Processing image: downloaded_images\non_violation\7.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\7.png: 480x640 3 persons, 1 motorcycle, 1 backpack, 1 umbrella, 189.9ms
# Speed: 5.0ms preprocess, 189.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\7.png
# Processing image: downloaded_images\non_violation\79590503.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\79590503.jpg: 480x640 4 persons, 1 motorcycle, 1 truck, 216.1ms
# Speed: 4.0ms preprocess, 216.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\79590503.jpg
# Processing image: downloaded_images\non_violation\8.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\8.jpeg: 640x640 2 persons, 1 motorcycle, 282.0ms
# Speed: 5.0ms preprocess, 282.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected image: output_images_mixed\8.jpeg
# Processing image: downloaded_images\non_violation\8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\8.jpg: 448x640 2 persons, 1 motorcycle, 168.3ms
# Speed: 3.0ms preprocess, 168.3ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\8.jpg
# Processing image: downloaded_images\non_violation\9.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\9.jpg: 448x640 1 person, 1 motorcycle, 183.5ms
# Speed: 2.0ms preprocess, 183.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\9.jpg
# Processing image: downloaded_images\non_violation\92076367.webp
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\92076367.webp: 384x640 2 persons, 1 motorcycle, 171.2ms
# Speed: 2.0ms preprocess, 171.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\92076367.webp
# Processing image: downloaded_images\non_violation\b4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b4.jpg: 640x416 1 person, 1 motorcycle, 2 kites, 159.3ms
# Speed: 3.0ms preprocess, 159.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 416)
# Saved detected image: output_images_mixed\b4.jpg
# Processing image: downloaded_images\non_violation\b5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b5.jpg: 448x640 1 person, 1 car, 1 motorcycle, 209.5ms
# Speed: 3.0ms preprocess, 209.5ms inference, 3.1ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\b5.jpg
# Processing image: downloaded_images\non_violation\b6.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b6.jpeg: 416x640 2 persons, 1 motorcycle, 201.6ms
# Speed: 2.0ms preprocess, 201.6ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected image: output_images_mixed\b6.jpeg
# Processing image: downloaded_images\non_violation\b7.avif
# Failed to load image (cv2.imread returned None): b7.avif
# Processing image: downloaded_images\non_violation\bike.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\bike.jpg: 352x640 1 person, 1 motorcycle, 140.1ms
# Speed: 3.6ms preprocess, 140.1ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
# Saved detected image: output_images_mixed\bike.jpg
# Processing image: downloaded_images\non_violation\Helmet.6 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Helmet.6 (1).jpg: 416x640 2 persons, 1 motorcycle, 1 bus, 157.1ms
# Speed: 2.0ms preprocess, 157.1ms inference, 5.4ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected image: output_images_mixed\Helmet.6 (1).jpg
# Processing image: downloaded_images\non_violation\Helmet.8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Helmet.8.jpg: 448x640 2 persons, 1 motorcycle, 232.7ms
# Speed: 2.5ms preprocess, 232.7ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\Helmet.8.jpg
# Processing image: downloaded_images\non_violation\helmet.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet.jpg: 480x640 5 persons, 183.8ms
# Speed: 3.0ms preprocess, 183.8ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\helmet.jpg
# Processing image: downloaded_images\non_violation\helmet1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet1.jpg: 416x640 2 persons, 156.7ms
# Speed: 2.0ms preprocess, 156.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected image: output_images_mixed\helmet1.jpg
# Processing image: downloaded_images\non_violation\helmet10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet10.jpg: 640x480 2 persons, 1 motorcycle, 179.5ms
# Speed: 2.0ms preprocess, 179.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Saved detected image: output_images_mixed\helmet10.jpg
# Processing image: downloaded_images\non_violation\helmet2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet2.jpg: 512x640 2 persons, 1 car, 1 motorcycle, 217.2ms
# Speed: 2.1ms preprocess, 217.2ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected image: output_images_mixed\helmet2.jpg
# Processing image: downloaded_images\non_violation\helmet3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet3.jpg: 416x640 2 persons, 1 motorcycle, 175.2ms
# Speed: 3.2ms preprocess, 175.2ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected image: output_images_mixed\helmet3.jpg
# Processing image: downloaded_images\non_violation\helmet5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet5.jpg: 448x640 2 persons, 1 motorcycle, 183.9ms
# Speed: 2.0ms preprocess, 183.9ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\helmet5.jpg
# Processing image: downloaded_images\non_violation\helmet7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet7.jpg: 448x640 2 persons, 1 motorcycle, 2 trucks, 204.8ms
# Speed: 2.0ms preprocess, 204.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\helmet7.jpg
# Processing image: downloaded_images\non_violation\images (10).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (10).jpg: 448x640 1 person, 184.2ms
# Speed: 3.0ms preprocess, 184.2ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\images (10).jpg
# Processing image: downloaded_images\non_violation\images (5).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (5).jpg: 448x640 3 persons, 1 motorcycle, 203.7ms
# Speed: 2.2ms preprocess, 203.7ms inference, 3.4ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\images (5).jpg
# Processing image: downloaded_images\non_violation\images (6).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (6).jpg: 448x640 2 persons, 1 motorcycle, 186.7ms
# Speed: 2.0ms preprocess, 186.7ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\images (6).jpg
# Processing image: downloaded_images\non_violation\images (7).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (7).jpg: 384x640 2 persons, 1 baseball glove, 151.8ms
# Speed: 2.0ms preprocess, 151.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\images (7).jpg
# Processing image: downloaded_images\non_violation\Image_02_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_02_Vishal_Pal.jpg: 640x448 3 persons, 1 motorcycle, 182.5ms
# Speed: 2.0ms preprocess, 182.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 448)
# Saved detected image: output_images_mixed\Image_02_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_03_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_03_Vishal_Pal.jpg: 512x640 3 persons, 1 motorcycle, 217.5ms
# Speed: 3.9ms preprocess, 217.5ms inference, 5.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected image: output_images_mixed\Image_03_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_06_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_06_Vishal_Pal.jpg: 384x640 1 person, 1 car, 1 motorcycle, 1 truck, 164.4ms
# Speed: 3.5ms preprocess, 164.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\Image_06_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_08_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_08_Vishal_Pal.jpg: 448x640 2 persons, 2 motorcycles, 197.8ms
# Speed: 5.0ms preprocess, 197.8ms inference, 5.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\Image_08_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\n.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\n.jpeg: 480x640 2 persons, 1 motorcycle, 3 backpacks, 252.2ms
# Speed: 2.0ms preprocess, 252.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\n.jpeg
# Processing image: downloaded_images\non_violation\n4.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\n4.jpeg: 640x480 1 person, 1 car, 2 motorcycles, 205.4ms
# Speed: 2.0ms preprocess, 205.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Saved detected image: output_images_mixed\n4.jpeg
# Processing image: downloaded_images\non_violation\nonviolation_10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_10.jpg: 448x640 1 person, 1 motorcycle, 183.3ms
# Speed: 4.2ms preprocess, 183.3ms inference, 5.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\nonviolation_10.jpg
# Processing image: downloaded_images\non_violation\nonviolation_2.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_2.png: 480x640 1 person, 1 motorcycle, 197.9ms
# Speed: 2.0ms preprocess, 197.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\nonviolation_2.png
# Processing image: downloaded_images\non_violation\nonviolation_3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_3.jpg: 544x640 3 persons, 1 motorcycle, 226.6ms
# Speed: 6.0ms preprocess, 226.6ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
# Saved detected image: output_images_mixed\nonviolation_3.jpg
# Processing image: downloaded_images\non_violation\nonviolation_4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_4.jpg: 640x512 1 person, 1 motorcycle, 208.4ms
# Speed: 2.1ms preprocess, 208.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
# Saved detected image: output_images_mixed\nonviolation_4.jpg
# Processing image: downloaded_images\non_violation\nonviolation_5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_5.jpg: 544x640 2 persons, 222.5ms
# Speed: 4.0ms preprocess, 222.5ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
# Saved detected image: output_images_mixed\nonviolation_5.jpg
# Processing image: downloaded_images\non_violation\nonviolation_6.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_6.jpg: 448x640 1 person, 1 motorcycle, 185.7ms
# Speed: 2.0ms preprocess, 185.7ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\nonviolation_6.jpg
# Processing image: downloaded_images\non_violation\nv1.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nv1.jpeg: 384x640 4 persons, 1 motorcycle, 149.3ms
# Speed: 2.0ms preprocess, 149.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\nv1.jpeg
# Processing image: downloaded_images\non_violation\pillion-rider.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\pillion-rider.jpg: 448x640 3 persons, 1 car, 1 motorcycle, 183.8ms
# Speed: 3.0ms preprocess, 183.8ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\pillion-rider.jpg
# Processing image: downloaded_images\non_violation\s1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\s1.jpg: 480x640 2 persons, 1 motorcycle, 185.4ms
# Speed: 3.0ms preprocess, 185.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\s1.jpg
# Processing image: downloaded_images\non_violation\s2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\s2.jpg: 384x640 2 persons, 2 backpacks, 1 sports ball, 159.5ms
# Speed: 2.0ms preprocess, 159.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\s2.jpg
# Processing directory: downloaded_images\violation
# Files in directory (43 items): ['100407182.webp', '2.jpg', '3.jpg', '3.png', '3007806.JPG', '65826504.jpg', '7.jpg', '7.jpg.jpeg', '8 (1).jpg', '8.jpg', '8.jpg.jpeg', 'boymg0f7zs1b1.jpg', 'image 10.jpeg', 'image5.jpg', 'images (1).jpeg', 'images.jpeg', 'Image_03_Vishal_Pal.jpg', 'Image_07_Vishal_Pal.jpg', 'Image_09_Vishal_Pal.jpg', 'Non helmet.1.jpg', 'Non helmet.9.jpg', 'v10.jpg', 'v11.jpg', 'v12.jpg', 'v13.jpg', 'v14.jpg', 'v15.jpg', 'v16.jpg', 'v17.jpg', 'v3.jpeg', 'v3.jpg', 'v4.jpg', 'v5.jpg', 'v6.jpg', 'v7.jpg', 'v8.jpg', 'v9.jpg', 'violation5.jpg', 'violation8.jpg', 'violation_1.jpg', 'violation_2.jpg', 'violation_3.jpg', 'vio_4.jpg']
# Processing image: downloaded_images\violation\100407182.webp
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\100407182.webp: 384x640 8 persons, 5 cars, 3 motorcycles, 163.5ms
# Speed: 2.0ms preprocess, 163.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\100407182.webp
# Processing image: downloaded_images\violation\2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\2.jpg: 416x640 7 persons, 2 motorcycles, 183.4ms
# Speed: 2.0ms preprocess, 183.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected image: output_images_mixed\2.jpg
# Processing image: downloaded_images\violation\3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3.jpg: 384x640 1 person, 1 motorcycle, 167.8ms
# Speed: 2.0ms preprocess, 167.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\3.jpg
# Processing image: downloaded_images\violation\3.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3.png: 352x640 2 persons, 1 motorcycle, 148.2ms
# Speed: 2.0ms preprocess, 148.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
# Saved detected image: output_images_mixed\3.png
# Processing image: downloaded_images\violation\3007806.JPG
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3007806.JPG: 448x640 5 persons, 1 motorcycle, 183.1ms
# Speed: 3.0ms preprocess, 183.1ms inference, 4.6ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\3007806.JPG
# Processing image: downloaded_images\violation\65826504.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\65826504.jpg: 480x640 5 persons, 192.8ms
# Speed: 3.8ms preprocess, 192.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\65826504.jpg
# Processing image: downloaded_images\violation\7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\7.jpg: 480x640 5 persons, 1 motorcycle, 1 handbag, 198.4ms
# Speed: 3.0ms preprocess, 198.4ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\7.jpg
# Processing image: downloaded_images\violation\7.jpg.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\7.jpg.jpeg: 480x640 5 persons, 1 motorcycle, 193.0ms
# Speed: 3.0ms preprocess, 193.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\7.jpg.jpeg
# Processing image: downloaded_images\violation\8 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8 (1).jpg: 480x640 5 persons, 1 car, 1 backpack, 1 handbag, 170.1ms
# Speed: 3.0ms preprocess, 170.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\8 (1).jpg
# Processing image: downloaded_images\violation\8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8.jpg: 480x640 2 persons, 1 motorcycle, 1 truck, 188.9ms
# Speed: 3.0ms preprocess, 188.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\8.jpg
# Processing image: downloaded_images\violation\8.jpg.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8.jpg.jpeg: 480x640 2 persons, 1 car, 2 motorcycles, 198.8ms
# Speed: 4.1ms preprocess, 198.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\8.jpg.jpeg
# Processing image: downloaded_images\violation\boymg0f7zs1b1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\boymg0f7zs1b1.jpg: 448x640 3 persons, 1 motorcycle, 1 sports ball, 175.1ms
# Speed: 3.0ms preprocess, 175.1ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\boymg0f7zs1b1.jpg
# Processing image: downloaded_images\violation\image 10.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\image 10.jpeg: 352x640 3 persons, 3 cars, 1 motorcycle, 1 bus, 1 truck, 143.1ms
# Speed: 3.0ms preprocess, 143.1ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
# Saved detected image: output_images_mixed\image 10.jpeg
# Processing image: downloaded_images\violation\image5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\image5.jpg: 448x640 1 person, 1 motorcycle, 1 backpack, 162.7ms
# Speed: 3.0ms preprocess, 162.7ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected image: output_images_mixed\image5.jpg
# Processing image: downloaded_images\violation\images (1).jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\images (1).jpeg: 384x640 6 persons, 1 motorcycle, 171.7ms
# Speed: 2.8ms preprocess, 171.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\images (1).jpeg
# Processing image: downloaded_images\violation\images.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\images.jpeg: 544x640 6 persons, 2 cars, 1 motorcycle, 1 bus, 198.7ms
# Speed: 3.0ms preprocess, 198.7ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
# Saved detected image: output_images_mixed\images.jpeg
# Processing image: downloaded_images\violation\Image_03_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Image_03_Vishal_Pal.jpg: 512x640 5 persons, 1 motorcycle, 203.0ms
# Speed: 3.0ms preprocess, 203.0ms inference, 4.5ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected image: output_images_mixed\Image_03_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Image_07_Vishal_Pal.jpg
# Failed to load image (cv2.imread returned None): Image_07_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Image_09_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Image_09_Vishal_Pal.jpg: 640x320 3 persons, 2 motorcycles, 1 potted plant, 135.2ms
# Speed: 3.0ms preprocess, 135.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
# Saved detected image: output_images_mixed\Image_09_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Non helmet.1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Non helmet.1.jpg: 416x640 2 persons, 2 cars, 1 motorcycle, 1 bus, 2 trucks, 149.9ms
# Speed: 3.0ms preprocess, 149.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected image: output_images_mixed\Non helmet.1.jpg
# Processing image: downloaded_images\violation\Non helmet.9.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Non helmet.9.jpg: 640x288 2 persons, 1 motorcycle, 122.5ms
# Speed: 1.0ms preprocess, 122.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 288)
# Saved detected image: output_images_mixed\Non helmet.9.jpg
# Processing image: downloaded_images\violation\v10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v10.jpg: 640x640 3 persons, 1 motorcycle, 259.4ms
# Speed: 3.0ms preprocess, 259.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected image: output_images_mixed\v10.jpg
# Processing image: downloaded_images\violation\v11.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v11.jpg: 640x640 4 persons, 3 motorcycles, 1 handbag, 260.6ms
# Speed: 6.0ms preprocess, 260.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected image: output_images_mixed\v11.jpg
# Processing image: downloaded_images\violation\v12.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v12.jpg: 640x640 2 persons, 1 motorcycle, 288.9ms
# Speed: 4.0ms preprocess, 288.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected image: output_images_mixed\v12.jpg
# Processing image: downloaded_images\violation\v13.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v13.jpg: 352x640 6 persons, 1 motorcycle, 1 truck, 140.5ms
# Speed: 2.0ms preprocess, 140.5ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
# Saved detected image: output_images_mixed\v13.jpg
# Processing image: downloaded_images\violation\v14.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v14.jpg: 480x640 5 persons, 1 motorcycle, 1 umbrella, 197.6ms
# Speed: 2.0ms preprocess, 197.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\v14.jpg
# Processing image: downloaded_images\violation\v15.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v15.jpg: 640x640 6 persons, 2 motorcycles, 286.1ms
# Speed: 4.0ms preprocess, 286.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected image: output_images_mixed\v15.jpg
# Processing image: downloaded_images\violation\v16.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v16.jpg: 640x640 5 persons, 1 motorcycle, 246.7ms
# Speed: 3.0ms preprocess, 246.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected image: output_images_mixed\v16.jpg
# Processing image: downloaded_images\violation\v17.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v17.jpg: 480x640 4 persons, 1 motorcycle, 253.3ms
# Speed: 11.0ms preprocess, 253.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\v17.jpg
# Processing image: downloaded_images\violation\v3.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v3.jpeg: 416x640 3 persons, 3 motorcycles, 211.3ms
# Speed: 2.0ms preprocess, 211.3ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected image: output_images_mixed\v3.jpeg
# Processing image: downloaded_images\violation\v3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v3.jpg: 640x544 2 persons, 263.1ms
# Speed: 4.0ms preprocess, 263.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 544)
# Saved detected image: output_images_mixed\v3.jpg
# Processing image: downloaded_images\violation\v4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v4.jpg: 384x640 3 persons, 2 cars, 2 motorcycles, 208.4ms
# Speed: 3.0ms preprocess, 208.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\v4.jpg
# Processing image: downloaded_images\violation\v5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v5.jpg: 480x640 3 persons, 1 car, 1 motorcycle, 1 potted plant, 187.1ms
# Speed: 3.0ms preprocess, 187.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\v5.jpg
# Processing image: downloaded_images\violation\v6.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v6.jpg: 544x640 3 persons, 1 motorcycle, 1 handbag, 231.9ms
# Speed: 4.2ms preprocess, 231.9ms inference, 3.5ms postprocess per image at shape (1, 3, 544, 640)
# Saved detected image: output_images_mixed\v6.jpg
# Processing image: downloaded_images\violation\v7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v7.jpg: 640x640 2 persons, 262.2ms
# Speed: 3.0ms preprocess, 262.2ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected image: output_images_mixed\v7.jpg
# Processing image: downloaded_images\violation\v8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v8.jpg: 480x640 2 persons, 1 motorcycle, 243.7ms
# Speed: 4.4ms preprocess, 243.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\v8.jpg
# Processing image: downloaded_images\violation\v9.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v9.jpg: 480x640 3 persons, 1 motorcycle, 1 backpack, 1 handbag, 192.4ms
# Speed: 3.0ms preprocess, 192.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\v9.jpg
# Processing image: downloaded_images\violation\violation5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation5.jpg: 480x640 3 persons, 1 motorcycle, 185.4ms
# Speed: 3.0ms preprocess, 185.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\violation5.jpg
# Processing image: downloaded_images\violation\violation8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation8.jpg: 384x640 3 persons, 148.8ms
# Speed: 2.0ms preprocess, 148.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\violation8.jpg
# Processing image: downloaded_images\violation\violation_1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_1.jpg: 480x640 1 person, 1 motorcycle, 198.0ms
# Speed: 3.0ms preprocess, 198.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected image: output_images_mixed\violation_1.jpg
# Processing image: downloaded_images\violation\violation_2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_2.jpg: 384x640 4 persons, 1 car, 1 motorcycle, 156.6ms
# Speed: 2.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected image: output_images_mixed\violation_2.jpg
# Processing image: downloaded_images\violation\violation_3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_3.jpg: 416x640 3 persons, 2 motorcycles, 158.6ms
# Speed: 2.0ms preprocess, 158.6ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected image: output_images_mixed\violation_3.jpg
# Processing image: downloaded_images\violation\vio_4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\vio_4.jpg: 512x640 8 persons, 1 motorcycle, 199.9ms
# Speed: 3.0ms preprocess, 199.9ms inference, 2.9ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected image: output_images_mixed\vio_4.jpg

# %%
from ultralytics import YOLO
import cv2
import os

# Load your custom YOLO model for helmet detection
model_path = "Desktop/best (1).pt"
model = YOLO(model_path)

# Define directories
image_directory = "downloaded_images"
output_directory = "output_images_helmet"
os.makedirs(output_directory, exist_ok=True)

# Print image directory being used
print(f"Image directory: {image_directory}")

# Check if the directory exists
if not os.path.exists(image_directory):
    print(f"Directory does not exist: {image_directory}")
    exit()

# List the contents of the directory
directory_contents = os.listdir(image_directory)
print(f"Contents of directory ({len(directory_contents)} items): {directory_contents}")

# Process each item in the directory
for entry in directory_contents:
    entry_path = os.path.join(image_directory, entry)
    
    # Check if it's a directory
    if os.path.isdir(entry_path):
        print(f"Processing directory: {entry_path}")
        
        # List files in the directory
        files_in_directory = os.listdir(entry_path)
        print(f"Files in directory ({len(files_in_directory)} items): {files_in_directory}")
        
        # Process each file in the directory
        for image_name in files_in_directory:
            image_path = os.path.join(entry_path, image_name)
            print(f"Processing image: {image_path}")

            try:
                # Read the image
                image = cv2.imread(image_path)
                if image is None:
                    print(f"Failed to load image (cv2.imread returned None): {image_name}")
                    continue
                
                # Perform inference
                results = model(image_path)

                # Extract bounding boxes and labels
                boxes = results[0].boxes.xyxy.cpu().numpy()  # xyxy format
                classes = results[0].boxes.cls.cpu().numpy()  # class indices
                scores = results[0].boxes.conf.cpu().numpy()  # confidences
                labels = model.names  # Get class names from the model

                # Process each detected object
                helmet_detected = False
                for box, cls, conf in zip(boxes, classes, scores):
                    x1, y1, x2, y2 = box
                    label = labels[int(cls)]
                    if label == 'with helmet' and conf >= 0.3:  # Adjust confidence threshold as needed
                        helmet_detected = True
                        color = (0, 255, 0)  # Green for helmets
                        cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
                        cv2.putText(image, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

                if helmet_detected:
                    output_path = os.path.join(output_directory, image_name)
                    cv2.imwrite(output_path, image)
                    print(f"Saved detected helmet image: {output_path}")
                else:
                    print(f"No helmet detected in image: {image_name}")

            except Exception as e:
                print(f"Error processing image {image_name}: {e}")

    else:
        print(f"Skipping non-directory: {entry}")
# Out:
# Image directory: downloaded_images
# Contents of directory (2 items): ['non_violation', 'violation']
# Processing directory: downloaded_images\non_violation
# Files in directory (58 items): ['1.jpeg', '10 (1).jpg', '10.jpg', '1047207-helmets-1.jpg', '1115.jpg', '2 (1).jpg', '2 (2).jpg', '2.jpg', '2.png', '3 (1).jpg', '3.jpeg', '3.jpg', '4.jpg', '5.jpg', '5.png', '6.jpg', '6.png', '7.jpg', '7.png', '79590503.jpg', '8.jpeg', '8.jpg', '9.jpg', '92076367.webp', 'b4.jpg', 'b5.jpg', 'b6.jpeg', 'b7.avif', 'bike.jpg', 'Helmet.6 (1).jpg', 'Helmet.8.jpg', 'helmet.jpg', 'helmet1.jpg', 'helmet10.jpg', 'helmet2.jpg', 'helmet3.jpg', 'helmet5.jpg', 'helmet7.jpg', 'images (10).jpg', 'images (5).jpg', 'images (6).jpg', 'images (7).jpg', 'Image_02_Vishal_Pal.jpg', 'Image_03_Vishal_Pal.jpg', 'Image_06_Vishal_Pal.jpg', 'Image_08_Vishal_Pal.jpg', 'n.jpeg', 'n4.jpeg', 'nonviolation_10.jpg', 'nonviolation_2.png', 'nonviolation_3.jpg', 'nonviolation_4.jpg', 'nonviolation_5.jpg', 'nonviolation_6.jpg', 'nv1.jpeg', 'pillion-rider.jpg', 's1.jpg', 's2.jpg']
# Processing image: downloaded_images\non_violation\1.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1.jpeg: 640x416 1 with helmet, 155.8ms
# Speed: 2.0ms preprocess, 155.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
# Saved detected helmet image: output_images_helmet\1.jpeg
# Processing image: downloaded_images\non_violation\10 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\10 (1).jpg: 416x640 1 with helmet, 141.8ms
# Speed: 2.0ms preprocess, 141.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected helmet image: output_images_helmet\10 (1).jpg
# Processing image: downloaded_images\non_violation\10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\10.jpg: 384x640 1 without helmet, 138.5ms
# Speed: 1.0ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No helmet detected in image: 10.jpg
# Processing image: downloaded_images\non_violation\1047207-helmets-1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1047207-helmets-1.jpg: 384x640 2 with helmets, 144.5ms
# Speed: 2.0ms preprocess, 144.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\1047207-helmets-1.jpg
# Processing image: downloaded_images\non_violation\1115.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1115.jpg: 416x640 1 with helmet, 195.4ms
# Speed: 2.9ms preprocess, 195.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected helmet image: output_images_helmet\1115.jpg
# Processing image: downloaded_images\non_violation\2 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2 (1).jpg: 512x640 2 with helmets, 175.3ms
# Speed: 2.0ms preprocess, 175.3ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected helmet image: output_images_helmet\2 (1).jpg
# Processing image: downloaded_images\non_violation\2 (2).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2 (2).jpg: 640x480 1 without helmet, 1 with helmet, 178.3ms
# Speed: 3.1ms preprocess, 178.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Saved detected helmet image: output_images_helmet\2 (2).jpg
# Processing image: downloaded_images\non_violation\2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2.jpg: 480x640 1 with helmet, 196.6ms
# Speed: 2.0ms preprocess, 196.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected helmet image: output_images_helmet\2.jpg
# Processing image: downloaded_images\non_violation\2.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2.png: 640x416 1 with helmet, 171.6ms
# Speed: 4.5ms preprocess, 171.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
# Saved detected helmet image: output_images_helmet\2.png
# Processing image: downloaded_images\non_violation\3 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3 (1).jpg: 384x640 2 without helmets, 2 with helmets, 148.6ms
# Speed: 2.5ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\3 (1).jpg
# Processing image: downloaded_images\non_violation\3.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3.jpeg: 384x640 2 with helmets, 147.0ms
# Speed: 3.0ms preprocess, 147.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\3.jpeg
# Processing image: downloaded_images\non_violation\3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3.jpg: 384x640 1 without helmet, 153.2ms
# Speed: 2.1ms preprocess, 153.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No helmet detected in image: 3.jpg
# Processing image: downloaded_images\non_violation\4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\4.jpg: 384x640 1 with helmet, 167.8ms
# Speed: 2.0ms preprocess, 167.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\4.jpg
# Processing image: downloaded_images\non_violation\5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\5.jpg: 384x640 2 with helmets, 157.0ms
# Speed: 2.0ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\5.jpg
# Processing image: downloaded_images\non_violation\5.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\5.png: 448x640 2 with helmets, 168.4ms
# Speed: 3.0ms preprocess, 168.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\5.png
# Processing image: downloaded_images\non_violation\6.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\6.jpg: 384x640 2 with helmets, 149.9ms
# Speed: 2.0ms preprocess, 149.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\6.jpg
# Processing image: downloaded_images\non_violation\6.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\6.png: 576x640 2 with helmets, 222.9ms
# Speed: 5.0ms preprocess, 222.9ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# Saved detected helmet image: output_images_helmet\6.png
# Processing image: downloaded_images\non_violation\7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\7.jpg: 384x640 2 with helmets, 166.4ms
# Speed: 2.0ms preprocess, 166.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\7.jpg
# Processing image: downloaded_images\non_violation\7.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\7.png: 480x640 2 with helmets, 203.9ms
# Speed: 2.0ms preprocess, 203.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected helmet image: output_images_helmet\7.png
# Processing image: downloaded_images\non_violation\79590503.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\79590503.jpg: 480x640 2 with helmets, 212.5ms
# Speed: 3.0ms preprocess, 212.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected helmet image: output_images_helmet\79590503.jpg
# Processing image: downloaded_images\non_violation\8.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\8.jpeg: 640x640 2 with helmets, 261.4ms
# Speed: 7.4ms preprocess, 261.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected helmet image: output_images_helmet\8.jpeg
# Processing image: downloaded_images\non_violation\8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\8.jpg: 448x640 2 with helmets, 210.9ms
# Speed: 3.2ms preprocess, 210.9ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\8.jpg
# Processing image: downloaded_images\non_violation\9.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\9.jpg: 448x640 1 with helmet, 185.6ms
# Speed: 1.0ms preprocess, 185.6ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\9.jpg
# Processing image: downloaded_images\non_violation\92076367.webp
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\92076367.webp: 384x640 1 with helmet, 158.9ms
# Speed: 2.0ms preprocess, 158.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\92076367.webp
# Processing image: downloaded_images\non_violation\b4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b4.jpg: 640x416 1 with helmet, 165.2ms
# Speed: 1.0ms preprocess, 165.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
# Saved detected helmet image: output_images_helmet\b4.jpg
# Processing image: downloaded_images\non_violation\b5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b5.jpg: 448x640 1 with helmet, 171.6ms
# Speed: 3.1ms preprocess, 171.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\b5.jpg
# Processing image: downloaded_images\non_violation\b6.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b6.jpeg: 416x640 1 without helmet, 1 with helmet, 167.6ms
# Speed: 2.5ms preprocess, 167.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected helmet image: output_images_helmet\b6.jpeg
# Processing image: downloaded_images\non_violation\b7.avif
# Failed to load image (cv2.imread returned None): b7.avif
# Processing image: downloaded_images\non_violation\bike.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\bike.jpg: 352x640 (no detections), 120.5ms
# Speed: 1.0ms preprocess, 120.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# No helmet detected in image: bike.jpg
# Processing image: downloaded_images\non_violation\Helmet.6 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Helmet.6 (1).jpg: 416x640 2 with helmets, 159.9ms
# Speed: 2.0ms preprocess, 159.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected helmet image: output_images_helmet\Helmet.6 (1).jpg
# Processing image: downloaded_images\non_violation\Helmet.8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Helmet.8.jpg: 448x640 2 with helmets, 173.0ms
# Speed: 2.0ms preprocess, 173.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\Helmet.8.jpg
# Processing image: downloaded_images\non_violation\helmet.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet.jpg: 480x640 3 with helmets, 187.9ms
# Speed: 2.0ms preprocess, 187.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected helmet image: output_images_helmet\helmet.jpg
# Processing image: downloaded_images\non_violation\helmet1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet1.jpg: 416x640 2 with helmets, 159.8ms
# Speed: 4.7ms preprocess, 159.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected helmet image: output_images_helmet\helmet1.jpg
# Processing image: downloaded_images\non_violation\helmet10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet10.jpg: 640x480 1 without helmet, 1 with helmet, 183.1ms
# Speed: 2.3ms preprocess, 183.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# Saved detected helmet image: output_images_helmet\helmet10.jpg
# Processing image: downloaded_images\non_violation\helmet2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet2.jpg: 512x640 2 with helmets, 185.6ms
# Speed: 2.0ms preprocess, 185.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected helmet image: output_images_helmet\helmet2.jpg
# Processing image: downloaded_images\non_violation\helmet3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet3.jpg: 416x640 1 without helmet, 1 with helmet, 146.4ms
# Speed: 4.0ms preprocess, 146.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected helmet image: output_images_helmet\helmet3.jpg
# Processing image: downloaded_images\non_violation\helmet5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet5.jpg: 448x640 2 with helmets, 157.4ms
# Speed: 2.0ms preprocess, 157.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\helmet5.jpg
# Processing image: downloaded_images\non_violation\helmet7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet7.jpg: 448x640 2 with helmets, 159.6ms
# Speed: 2.1ms preprocess, 159.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\helmet7.jpg
# Processing image: downloaded_images\non_violation\images (10).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (10).jpg: 448x640 1 with helmet, 164.6ms
# Speed: 2.0ms preprocess, 164.6ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\images (10).jpg
# Processing image: downloaded_images\non_violation\images (5).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (5).jpg: 448x640 1 with helmet, 153.2ms
# Speed: 3.1ms preprocess, 153.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\images (5).jpg
# Processing image: downloaded_images\non_violation\images (6).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (6).jpg: 448x640 1 with helmet, 177.4ms
# Speed: 2.0ms preprocess, 177.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\images (6).jpg
# Processing image: downloaded_images\non_violation\images (7).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (7).jpg: 384x640 2 with helmets, 139.0ms
# Speed: 2.0ms preprocess, 139.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\images (7).jpg
# Processing image: downloaded_images\non_violation\Image_02_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_02_Vishal_Pal.jpg: 640x448 1 with helmet, 158.3ms
# Speed: 2.9ms preprocess, 158.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# Saved detected helmet image: output_images_helmet\Image_02_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_03_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_03_Vishal_Pal.jpg: 512x640 1 with helmet, 175.7ms
# Speed: 2.0ms preprocess, 175.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected helmet image: output_images_helmet\Image_03_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_06_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_06_Vishal_Pal.jpg: 384x640 1 with helmet, 176.3ms
# Speed: 2.0ms preprocess, 176.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\Image_06_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_08_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_08_Vishal_Pal.jpg: 448x640 2 with helmets, 165.7ms
# Speed: 3.0ms preprocess, 165.7ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\Image_08_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\n.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\n.jpeg: 480x640 2 without helmets, 1 with helmet, 166.8ms
# Speed: 3.1ms preprocess, 166.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected helmet image: output_images_helmet\n.jpeg
# Processing image: downloaded_images\non_violation\n4.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\n4.jpeg: 640x480 (no detections), 171.4ms
# Speed: 2.0ms preprocess, 171.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# No helmet detected in image: n4.jpeg
# Processing image: downloaded_images\non_violation\nonviolation_10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_10.jpg: 448x640 1 with helmet, 148.1ms
# Speed: 2.0ms preprocess, 148.1ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\nonviolation_10.jpg
# Processing image: downloaded_images\non_violation\nonviolation_2.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_2.png: 480x640 1 with helmet, 179.5ms
# Speed: 2.1ms preprocess, 179.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected helmet image: output_images_helmet\nonviolation_2.png
# Processing image: downloaded_images\non_violation\nonviolation_3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_3.jpg: 544x640 2 with helmets, 224.0ms
# Speed: 5.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# Saved detected helmet image: output_images_helmet\nonviolation_3.jpg
# Processing image: downloaded_images\non_violation\nonviolation_4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_4.jpg: 640x512 1 with helmet, 176.2ms
# Speed: 3.7ms preprocess, 176.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Saved detected helmet image: output_images_helmet\nonviolation_4.jpg
# Processing image: downloaded_images\non_violation\nonviolation_5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_5.jpg: 544x640 1 with helmet, 189.1ms
# Speed: 3.0ms preprocess, 189.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# Saved detected helmet image: output_images_helmet\nonviolation_5.jpg
# Processing image: downloaded_images\non_violation\nonviolation_6.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_6.jpg: 448x640 1 with helmet, 168.5ms
# Speed: 2.1ms preprocess, 168.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\nonviolation_6.jpg
# Processing image: downloaded_images\non_violation\nv1.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nv1.jpeg: 384x640 2 with helmets, 138.1ms
# Speed: 2.0ms preprocess, 138.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\nv1.jpeg
# Processing image: downloaded_images\non_violation\pillion-rider.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\pillion-rider.jpg: 448x640 2 with helmets, 175.5ms
# Speed: 2.0ms preprocess, 175.5ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\pillion-rider.jpg
# Processing image: downloaded_images\non_violation\s1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\s1.jpg: 480x640 2 with helmets, 157.4ms
# Speed: 3.0ms preprocess, 157.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected helmet image: output_images_helmet\s1.jpg
# Processing image: downloaded_images\non_violation\s2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\s2.jpg: 384x640 2 with helmets, 143.6ms
# Speed: 2.1ms preprocess, 143.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\s2.jpg
# Processing directory: downloaded_images\violation
# Files in directory (43 items): ['100407182.webp', '2.jpg', '3.jpg', '3.png', '3007806.JPG', '65826504.jpg', '7.jpg', '7.jpg.jpeg', '8 (1).jpg', '8.jpg', '8.jpg.jpeg', 'boymg0f7zs1b1.jpg', 'image 10.jpeg', 'image5.jpg', 'images (1).jpeg', 'images.jpeg', 'Image_03_Vishal_Pal.jpg', 'Image_07_Vishal_Pal.jpg', 'Image_09_Vishal_Pal.jpg', 'Non helmet.1.jpg', 'Non helmet.9.jpg', 'v10.jpg', 'v11.jpg', 'v12.jpg', 'v13.jpg', 'v14.jpg', 'v15.jpg', 'v16.jpg', 'v17.jpg', 'v3.jpeg', 'v3.jpg', 'v4.jpg', 'v5.jpg', 'v6.jpg', 'v7.jpg', 'v8.jpg', 'v9.jpg', 'violation5.jpg', 'violation8.jpg', 'violation_1.jpg', 'violation_2.jpg', 'violation_3.jpg', 'vio_4.jpg']
# Processing image: downloaded_images\violation\100407182.webp
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\100407182.webp: 384x640 2 with helmets, 163.8ms
# Speed: 2.0ms preprocess, 163.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\100407182.webp
# Processing image: downloaded_images\violation\2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\2.jpg: 416x640 3 without helmets, 159.4ms
# Speed: 3.3ms preprocess, 159.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# No helmet detected in image: 2.jpg
# Processing image: downloaded_images\violation\3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3.jpg: 384x640 1 without helmet, 144.0ms
# Speed: 2.0ms preprocess, 144.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No helmet detected in image: 3.jpg
# Processing image: downloaded_images\violation\3.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3.png: 352x640 1 without helmet, 1 with helmet, 128.2ms
# Speed: 2.1ms preprocess, 128.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Saved detected helmet image: output_images_helmet\3.png
# Processing image: downloaded_images\violation\3007806.JPG
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3007806.JPG: 448x640 1 without helmet, 1 with helmet, 168.6ms
# Speed: 2.1ms preprocess, 168.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\3007806.JPG
# Processing image: downloaded_images\violation\65826504.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\65826504.jpg: 480x640 3 without helmets, 207.0ms
# Speed: 3.0ms preprocess, 207.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# No helmet detected in image: 65826504.jpg
# Processing image: downloaded_images\violation\7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\7.jpg: 480x640 2 without helmets, 1 with helmet, 189.5ms
# Speed: 3.1ms preprocess, 189.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected helmet image: output_images_helmet\7.jpg
# Processing image: downloaded_images\violation\7.jpg.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\7.jpg.jpeg: 480x640 5 without helmets, 162.8ms
# Speed: 2.1ms preprocess, 162.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No helmet detected in image: 7.jpg.jpeg
# Processing image: downloaded_images\violation\8 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8 (1).jpg: 480x640 2 without helmets, 2 with helmets, 195.0ms
# Speed: 2.9ms preprocess, 195.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected helmet image: output_images_helmet\8 (1).jpg
# Processing image: downloaded_images\violation\8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8.jpg: 480x640 2 without helmets, 177.9ms
# Speed: 3.0ms preprocess, 177.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No helmet detected in image: 8.jpg
# Processing image: downloaded_images\violation\8.jpg.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8.jpg.jpeg: 480x640 2 without helmets, 188.7ms
# Speed: 2.1ms preprocess, 188.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No helmet detected in image: 8.jpg.jpeg
# Processing image: downloaded_images\violation\boymg0f7zs1b1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\boymg0f7zs1b1.jpg: 448x640 1 without helmet, 1 with helmet, 191.1ms
# Speed: 2.0ms preprocess, 191.1ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected helmet image: output_images_helmet\boymg0f7zs1b1.jpg
# Processing image: downloaded_images\violation\image 10.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\image 10.jpeg: 352x640 2 without helmets, 154.7ms
# Speed: 2.0ms preprocess, 154.7ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
# No helmet detected in image: image 10.jpeg
# Processing image: downloaded_images\violation\image5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\image5.jpg: 448x640 2 without helmets, 161.3ms
# Speed: 4.0ms preprocess, 161.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# No helmet detected in image: image5.jpg
# Processing image: downloaded_images\violation\images (1).jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\images (1).jpeg: 384x640 2 without helmets, 162.9ms
# Speed: 1.0ms preprocess, 162.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No helmet detected in image: images (1).jpeg
# Processing image: downloaded_images\violation\images.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\images.jpeg: 544x640 3 without helmets, 202.2ms
# Speed: 3.0ms preprocess, 202.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No helmet detected in image: images.jpeg
# Processing image: downloaded_images\violation\Image_03_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Image_03_Vishal_Pal.jpg: 512x640 1 without helmet, 1 with helmet, 197.4ms
# Speed: 2.9ms preprocess, 197.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected helmet image: output_images_helmet\Image_03_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Image_07_Vishal_Pal.jpg
# Failed to load image (cv2.imread returned None): Image_07_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Image_09_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Image_09_Vishal_Pal.jpg: 640x320 1 without helmet, 132.8ms
# Speed: 2.0ms preprocess, 132.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
# No helmet detected in image: Image_09_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Non helmet.1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Non helmet.1.jpg: 416x640 2 without helmets, 164.0ms
# Speed: 3.0ms preprocess, 164.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# No helmet detected in image: Non helmet.1.jpg
# Processing image: downloaded_images\violation\Non helmet.9.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Non helmet.9.jpg: 640x288 2 without helmets, 125.5ms
# Speed: 2.0ms preprocess, 125.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 288)
# No helmet detected in image: Non helmet.9.jpg
# Processing image: downloaded_images\violation\v10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v10.jpg: 640x640 1 with helmet, 240.8ms
# Speed: 3.1ms preprocess, 240.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected helmet image: output_images_helmet\v10.jpg
# Processing image: downloaded_images\violation\v11.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v11.jpg: 640x640 3 without helmets, 221.9ms
# Speed: 3.4ms preprocess, 221.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No helmet detected in image: v11.jpg
# Processing image: downloaded_images\violation\v12.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v12.jpg: 640x640 2 with helmets, 219.9ms
# Speed: 3.0ms preprocess, 219.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected helmet image: output_images_helmet\v12.jpg
# Processing image: downloaded_images\violation\v13.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v13.jpg: 352x640 3 without helmets, 137.0ms
# Speed: 2.0ms preprocess, 137.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# No helmet detected in image: v13.jpg
# Processing image: downloaded_images\violation\v14.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v14.jpg: 480x640 3 without helmets, 164.3ms
# Speed: 3.1ms preprocess, 164.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# No helmet detected in image: v14.jpg
# Processing image: downloaded_images\violation\v15.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v15.jpg: 640x640 2 with helmets, 219.1ms
# Speed: 2.0ms preprocess, 219.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected helmet image: output_images_helmet\v15.jpg
# Processing image: downloaded_images\violation\v16.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v16.jpg: 640x640 3 without helmets, 218.7ms
# Speed: 5.0ms preprocess, 218.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No helmet detected in image: v16.jpg
# Processing image: downloaded_images\violation\v17.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v17.jpg: 480x640 3 without helmets, 1 with helmet, 162.7ms
# Speed: 3.1ms preprocess, 162.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected helmet image: output_images_helmet\v17.jpg
# Processing image: downloaded_images\violation\v3.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v3.jpeg: 416x640 2 without helmets, 145.4ms
# Speed: 2.0ms preprocess, 145.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# No helmet detected in image: v3.jpeg
# Processing image: downloaded_images\violation\v3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v3.jpg: 640x544 2 without helmets, 191.7ms
# Speed: 3.0ms preprocess, 191.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 544)
# No helmet detected in image: v3.jpg
# Processing image: downloaded_images\violation\v4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v4.jpg: 384x640 1 without helmet, 2 with helmets, 139.2ms
# Speed: 3.0ms preprocess, 139.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected helmet image: output_images_helmet\v4.jpg
# Processing image: downloaded_images\violation\v5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v5.jpg: 480x640 2 without helmets, 164.3ms
# Speed: 2.0ms preprocess, 164.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# No helmet detected in image: v5.jpg
# Processing image: downloaded_images\violation\v6.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v6.jpg: 544x640 3 without helmets, 179.1ms
# Speed: 3.0ms preprocess, 179.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No helmet detected in image: v6.jpg
# Processing image: downloaded_images\violation\v7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v7.jpg: 640x640 1 with helmet, 208.0ms
# Speed: 3.0ms preprocess, 208.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No helmet detected in image: v7.jpg
# Processing image: downloaded_images\violation\v8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v8.jpg: 480x640 2 without helmets, 1 with helmet, 159.0ms
# Speed: 3.0ms preprocess, 159.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected helmet image: output_images_helmet\v8.jpg
# Processing image: downloaded_images\violation\v9.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v9.jpg: 480x640 3 without helmets, 163.4ms
# Speed: 2.9ms preprocess, 163.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No helmet detected in image: v9.jpg
# Processing image: downloaded_images\violation\violation5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation5.jpg: 480x640 3 without helmets, 168.6ms
# Speed: 2.0ms preprocess, 168.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# No helmet detected in image: violation5.jpg
# Processing image: downloaded_images\violation\violation8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation8.jpg: 384x640 2 without helmets, 136.0ms
# Speed: 2.0ms preprocess, 136.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No helmet detected in image: violation8.jpg
# Processing image: downloaded_images\violation\violation_1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_1.jpg: 480x640 1 without helmet, 165.3ms
# Speed: 3.2ms preprocess, 165.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# No helmet detected in image: violation_1.jpg
# Processing image: downloaded_images\violation\violation_2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_2.jpg: 384x640 1 without helmet, 126.4ms
# Speed: 2.9ms preprocess, 126.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No helmet detected in image: violation_2.jpg
# Processing image: downloaded_images\violation\violation_3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_3.jpg: 416x640 1 without helmet, 1 with helmet, 188.5ms
# Speed: 2.0ms preprocess, 188.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected helmet image: output_images_helmet\violation_3.jpg
# Processing image: downloaded_images\violation\vio_4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\vio_4.jpg: 512x640 3 without helmets, 174.4ms
# Speed: 3.5ms preprocess, 174.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No helmet detected in image: vio_4.jpg

# %%
from ultralytics import YOLO
import cv2
import os

# Load your custom YOLO model for helmet detection
helmet_model_path = "Desktop/best (1).pt"
helmet_model = YOLO(helmet_model_path)

# Load the YOLOv8 model for general object detection
general_model_path = "yolov8n.pt"  # or any other pre-trained YOLOv8 model
general_model = YOLO(general_model_path)

# Define directories
image_directory = "downloaded_images"
output_directory = "output_images_combined"
os.makedirs(output_directory, exist_ok=True)

# Print image directory being used
print(f"Image directory: {image_directory}")

# Check if the directory exists
if not os.path.exists(image_directory):
    print(f"Directory does not exist: {image_directory}")
    exit()

# List the contents of the directory
directory_contents = os.listdir(image_directory)
print(f"Contents of directory ({len(directory_contents)} items): {directory_contents}")

# Process each item in the directory
for entry in directory_contents:
    entry_path = os.path.join(image_directory, entry)
    
    # Check if it's a directory
    if os.path.isdir(entry_path):
        print(f"Processing directory: {entry_path}")
        
        # List files in the directory
        files_in_directory = os.listdir(entry_path)
        print(f"Files in directory ({len(files_in_directory)} items): {files_in_directory}")
        
        # Process each file in the directory
        for image_name in files_in_directory:
            image_path = os.path.join(entry_path, image_name)
            print(f"Processing image: {image_path}")

            try:
                # Read the image
                image = cv2.imread(image_path)
                if image is None:
                    print(f"Failed to load image (cv2.imread returned None): {image_name}")
                    continue
                
                # Perform inference using the helmet model
                helmet_results = helmet_model(image_path)

                # Perform inference using the general object detection model
                general_results = general_model(image_path)

                # Extract bounding boxes and labels for helmet model
                helmet_boxes = helmet_results[0].boxes.xyxy.cpu().numpy()  # xyxy format
                helmet_classes = helmet_results[0].boxes.cls.cpu().numpy()  # class indices
                helmet_scores = helmet_results[0].boxes.conf.cpu().numpy()  # confidences
                helmet_labels = helmet_model.names

                # Extract bounding boxes and labels for general model
                general_boxes = general_results[0].boxes.xyxy.cpu().numpy()  # xyxy format
                general_classes = general_results[0].boxes.cls.cpu().numpy()  # class indices
                general_scores = general_results[0].boxes.conf.cpu().numpy()  # confidences
                general_labels = general_model.names

                # Process each detected object from helmet model
                for box, cls, conf in zip(helmet_boxes, helmet_classes, helmet_scores):
                    x1, y1, x2, y2 = box
                    label = helmet_labels[int(cls)]
                    if label == 'with helmet' and conf >= 0.3:  # Adjust confidence threshold as needed
                        color = (0, 255, 0)  # Green for helmets
                        cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
                        cv2.putText(image, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
                    elif label == 'without helmet' and conf >= 0.3:
                        color = (0, 0, 255)  # Red for without helmets
                        cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
                        cv2.putText(image, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

                # Process each detected object from general model
                for box, cls, conf in zip(general_boxes, general_classes, general_scores):
                    x1, y1, x2, y2 = box
                    label = general_labels[int(cls)]
                    if label == 'person' and conf >= 0.3:
                        color = (255, 0, 0)  # Blue for people
                        cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
                        cv2.putText(image, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
                    elif label in ['bicycle', 'motorcycle'] and conf >= 0.3:
                        color = (255, 255, 0)  # Cyan for bikes
                        cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
                        cv2.putText(image, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

                output_path = os.path.join(output_directory, image_name)
                cv2.imwrite(output_path, image)
                print(f"Saved detected objects image: {output_path}")

            except Exception as e:
                print(f"Error processing image {image_name}: {e}")

    else:
        print(f"Skipping non-directory: {entry}")
# Out:
# Image directory: downloaded_images
# Contents of directory (2 items): ['non_violation', 'violation']
# Processing directory: downloaded_images\non_violation
# Files in directory (58 items): ['1.jpeg', '10 (1).jpg', '10.jpg', '1047207-helmets-1.jpg', '1115.jpg', '2 (1).jpg', '2 (2).jpg', '2.jpg', '2.png', '3 (1).jpg', '3.jpeg', '3.jpg', '4.jpg', '5.jpg', '5.png', '6.jpg', '6.png', '7.jpg', '7.png', '79590503.jpg', '8.jpeg', '8.jpg', '9.jpg', '92076367.webp', 'b4.jpg', 'b5.jpg', 'b6.jpeg', 'b7.avif', 'bike.jpg', 'Helmet.6 (1).jpg', 'Helmet.8.jpg', 'helmet.jpg', 'helmet1.jpg', 'helmet10.jpg', 'helmet2.jpg', 'helmet3.jpg', 'helmet5.jpg', 'helmet7.jpg', 'images (10).jpg', 'images (5).jpg', 'images (6).jpg', 'images (7).jpg', 'Image_02_Vishal_Pal.jpg', 'Image_03_Vishal_Pal.jpg', 'Image_06_Vishal_Pal.jpg', 'Image_08_Vishal_Pal.jpg', 'n.jpeg', 'n4.jpeg', 'nonviolation_10.jpg', 'nonviolation_2.png', 'nonviolation_3.jpg', 'nonviolation_4.jpg', 'nonviolation_5.jpg', 'nonviolation_6.jpg', 'nv1.jpeg', 'pillion-rider.jpg', 's1.jpg', 's2.jpg']
# Processing image: downloaded_images\non_violation\1.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1.jpeg: 640x416 1 with helmet, 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1.jpeg: 640x416 1 person, 1 motorcycle, 188.3ms
# Speed: 1.9ms preprocess, 188.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
# Saved detected objects image: output_images_combined\1.jpeg
# Processing image: downloaded_images\non_violation\10 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\10 (1).jpg: 416x640 1 with helmet, 154.9ms
# Speed: 3.0ms preprocess, 154.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\10 (1).jpg: 416x640 2 persons, 1 motorcycle, 173.2ms
# Speed: 1.0ms preprocess, 173.2ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected objects image: output_images_combined\10 (1).jpg
# Processing image: downloaded_images\non_violation\10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\10.jpg: 384x640 1 without helmet, 140.4ms
# Speed: 2.0ms preprocess, 140.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\10.jpg: 384x640 1 person, 1 car, 1 motorcycle, 162.4ms
# Speed: 2.0ms preprocess, 162.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\10.jpg
# Processing image: downloaded_images\non_violation\1047207-helmets-1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1047207-helmets-1.jpg: 384x640 2 with helmets, 135.9ms
# Speed: 2.0ms preprocess, 135.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1047207-helmets-1.jpg: 384x640 2 persons, 1 motorcycle, 169.7ms
# Speed: 2.0ms preprocess, 169.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\1047207-helmets-1.jpg
# Processing image: downloaded_images\non_violation\1115.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1115.jpg: 416x640 1 with helmet, 193.2ms
# Speed: 2.0ms preprocess, 193.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\1115.jpg: 416x640 2 persons, 1 motorcycle, 177.3ms
# Speed: 2.5ms preprocess, 177.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected objects image: output_images_combined\1115.jpg
# Processing image: downloaded_images\non_violation\2 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2 (1).jpg: 512x640 2 with helmets, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2 (1).jpg: 512x640 2 persons, 1 car, 1 motorcycle, 220.5ms
# Speed: 3.0ms preprocess, 220.5ms inference, 12.6ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected objects image: output_images_combined\2 (1).jpg
# Processing image: downloaded_images\non_violation\2 (2).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2 (2).jpg: 640x480 1 without helmet, 1 with helmet, 188.2ms
# Speed: 3.0ms preprocess, 188.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2 (2).jpg: 640x480 2 persons, 1 motorcycle, 205.3ms
# Speed: 2.0ms preprocess, 205.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Saved detected objects image: output_images_combined\2 (2).jpg
# Processing image: downloaded_images\non_violation\2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2.jpg: 480x640 1 with helmet, 176.1ms
# Speed: 3.5ms preprocess, 176.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2.jpg: 480x640 1 person, 1 motorcycle, 184.0ms
# Speed: 3.0ms preprocess, 184.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\2.jpg
# Processing image: downloaded_images\non_violation\2.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2.png: 640x416 1 with helmet, 152.4ms
# Speed: 3.0ms preprocess, 152.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\2.png: 640x416 1 person, 1 motorcycle, 169.8ms
# Speed: 2.0ms preprocess, 169.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 416)
# Saved detected objects image: output_images_combined\2.png
# Processing image: downloaded_images\non_violation\3 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3 (1).jpg: 384x640 2 without helmets, 2 with helmets, 172.7ms
# Speed: 2.0ms preprocess, 172.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3 (1).jpg: 384x640 5 persons, 1 motorcycle, 180.5ms
# Speed: 3.0ms preprocess, 180.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\3 (1).jpg
# Processing image: downloaded_images\non_violation\3.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3.jpeg: 384x640 2 with helmets, 149.2ms
# Speed: 2.0ms preprocess, 149.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3.jpeg: 384x640 3 persons, 1 motorcycle, 2 backpacks, 165.3ms
# Speed: 2.0ms preprocess, 165.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\3.jpeg
# Processing image: downloaded_images\non_violation\3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3.jpg: 384x640 1 without helmet, 150.6ms
# Speed: 1.6ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\3.jpg: 384x640 1 person, 1 motorcycle, 201.2ms
# Speed: 2.0ms preprocess, 201.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\3.jpg
# Processing image: downloaded_images\non_violation\4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\4.jpg: 384x640 1 with helmet, 139.8ms
# Speed: 2.0ms preprocess, 139.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\4.jpg: 384x640 2 persons, 1 motorcycle, 157.5ms
# Speed: 2.0ms preprocess, 157.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\4.jpg
# Processing image: downloaded_images\non_violation\5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\5.jpg: 384x640 2 with helmets, 159.4ms
# Speed: 1.1ms preprocess, 159.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\5.jpg: 384x640 2 persons, 1 motorcycle, 164.7ms
# Speed: 1.0ms preprocess, 164.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\5.jpg
# Processing image: downloaded_images\non_violation\5.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\5.png: 448x640 2 with helmets, 161.3ms
# Speed: 3.0ms preprocess, 161.3ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\5.png: 448x640 3 persons, 1 car, 1 motorcycle, 175.0ms
# Speed: 2.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\5.png
# Processing image: downloaded_images\non_violation\6.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\6.jpg: 384x640 2 with helmets, 143.2ms
# Speed: 2.0ms preprocess, 143.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\6.jpg: 384x640 3 persons, 1 motorcycle, 1 bus, 1 truck, 169.2ms
# Speed: 2.0ms preprocess, 169.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\6.jpg
# Processing image: downloaded_images\non_violation\6.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\6.png: 576x640 2 with helmets, 196.5ms
# Speed: 5.0ms preprocess, 196.5ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\6.png: 576x640 2 persons, 1 motorcycle, 204.5ms
# Speed: 4.0ms preprocess, 204.5ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 640)
# Saved detected objects image: output_images_combined\6.png
# Processing image: downloaded_images\non_violation\7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\7.jpg: 384x640 2 with helmets, 145.8ms
# Speed: 3.0ms preprocess, 145.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\7.jpg: 384x640 2 persons, 1 motorcycle, 144.7ms
# Speed: 2.1ms preprocess, 144.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\7.jpg
# Processing image: downloaded_images\non_violation\7.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\7.png: 480x640 2 with helmets, 188.2ms
# Speed: 2.0ms preprocess, 188.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\7.png: 480x640 3 persons, 1 motorcycle, 1 backpack, 1 umbrella, 203.6ms
# Speed: 2.0ms preprocess, 203.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\7.png
# Processing image: downloaded_images\non_violation\79590503.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\79590503.jpg: 480x640 2 with helmets, 176.6ms
# Speed: 3.0ms preprocess, 176.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\79590503.jpg: 480x640 4 persons, 1 motorcycle, 1 truck, 191.2ms
# Speed: 1.9ms preprocess, 191.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\79590503.jpg
# Processing image: downloaded_images\non_violation\8.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\8.jpeg: 640x640 2 with helmets, 243.7ms
# Speed: 4.0ms preprocess, 243.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\8.jpeg: 640x640 2 persons, 1 motorcycle, 247.8ms
# Speed: 4.0ms preprocess, 247.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected objects image: output_images_combined\8.jpeg
# Processing image: downloaded_images\non_violation\8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\8.jpg: 448x640 2 with helmets, 169.7ms
# Speed: 2.0ms preprocess, 169.7ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\8.jpg: 448x640 2 persons, 1 motorcycle, 185.4ms
# Speed: 3.0ms preprocess, 185.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\8.jpg
# Processing image: downloaded_images\non_violation\9.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\9.jpg: 448x640 1 with helmet, 150.0ms
# Speed: 2.0ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\9.jpg: 448x640 1 person, 1 motorcycle, 171.6ms
# Speed: 2.0ms preprocess, 171.6ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\9.jpg
# Processing image: downloaded_images\non_violation\92076367.webp
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\92076367.webp: 384x640 1 with helmet, 129.4ms
# Speed: 2.0ms preprocess, 129.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\92076367.webp: 384x640 2 persons, 1 motorcycle, 152.5ms
# Speed: 1.0ms preprocess, 152.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\92076367.webp
# Processing image: downloaded_images\non_violation\b4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b4.jpg: 640x416 1 with helmet, 150.2ms
# Speed: 1.9ms preprocess, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b4.jpg: 640x416 1 person, 1 motorcycle, 2 kites, 156.9ms
# Speed: 2.5ms preprocess, 156.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
# Saved detected objects image: output_images_combined\b4.jpg
# Processing image: downloaded_images\non_violation\b5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b5.jpg: 448x640 1 with helmet, 163.2ms
# Speed: 2.1ms preprocess, 163.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b5.jpg: 448x640 1 person, 1 car, 1 motorcycle, 166.3ms
# Speed: 2.0ms preprocess, 166.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\b5.jpg
# Processing image: downloaded_images\non_violation\b6.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b6.jpeg: 416x640 1 without helmet, 1 with helmet, 167.4ms
# Speed: 2.0ms preprocess, 167.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\b6.jpeg: 416x640 2 persons, 1 motorcycle, 156.8ms
# Speed: 3.3ms preprocess, 156.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected objects image: output_images_combined\b6.jpeg
# Processing image: downloaded_images\non_violation\b7.avif
# Failed to load image (cv2.imread returned None): b7.avif
# Processing image: downloaded_images\non_violation\bike.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\bike.jpg: 352x640 (no detections), 119.6ms
# Speed: 2.0ms preprocess, 119.6ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\bike.jpg: 352x640 1 person, 1 motorcycle, 136.4ms
# Speed: 1.0ms preprocess, 136.4ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
# Saved detected objects image: output_images_combined\bike.jpg
# Processing image: downloaded_images\non_violation\Helmet.6 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Helmet.6 (1).jpg: 416x640 2 with helmets, 153.9ms
# Speed: 3.0ms preprocess, 153.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Helmet.6 (1).jpg: 416x640 2 persons, 1 motorcycle, 1 bus, 150.9ms
# Speed: 3.0ms preprocess, 150.9ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected objects image: output_images_combined\Helmet.6 (1).jpg
# Processing image: downloaded_images\non_violation\Helmet.8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Helmet.8.jpg: 448x640 2 with helmets, 148.8ms
# Speed: 4.0ms preprocess, 148.8ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Helmet.8.jpg: 448x640 2 persons, 1 motorcycle, 191.8ms
# Speed: 3.2ms preprocess, 191.8ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\Helmet.8.jpg
# Processing image: downloaded_images\non_violation\helmet.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet.jpg: 480x640 3 with helmets, 183.3ms
# Speed: 2.8ms preprocess, 183.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet.jpg: 480x640 5 persons, 175.8ms
# Speed: 2.0ms preprocess, 175.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\helmet.jpg
# Processing image: downloaded_images\non_violation\helmet1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet1.jpg: 416x640 2 with helmets, 161.2ms
# Speed: 1.0ms preprocess, 161.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet1.jpg: 416x640 2 persons, 160.0ms
# Speed: 1.1ms preprocess, 160.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected objects image: output_images_combined\helmet1.jpg
# Processing image: downloaded_images\non_violation\helmet10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet10.jpg: 640x480 1 without helmet, 1 with helmet, 190.6ms
# Speed: 3.0ms preprocess, 190.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet10.jpg: 640x480 2 persons, 1 motorcycle, 174.8ms
# Speed: 3.1ms preprocess, 174.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
# Saved detected objects image: output_images_combined\helmet10.jpg
# Processing image: downloaded_images\non_violation\helmet2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet2.jpg: 512x640 2 with helmets, 170.2ms
# Speed: 3.0ms preprocess, 170.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet2.jpg: 512x640 2 persons, 1 car, 1 motorcycle, 194.5ms
# Speed: 2.0ms preprocess, 194.5ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected objects image: output_images_combined\helmet2.jpg
# Processing image: downloaded_images\non_violation\helmet3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet3.jpg: 416x640 1 without helmet, 1 with helmet, 142.7ms
# Speed: 3.0ms preprocess, 142.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet3.jpg: 416x640 2 persons, 1 motorcycle, 155.1ms
# Speed: 2.1ms preprocess, 155.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected objects image: output_images_combined\helmet3.jpg
# Processing image: downloaded_images\non_violation\helmet5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet5.jpg: 448x640 2 with helmets, 156.7ms
# Speed: 2.0ms preprocess, 156.7ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet5.jpg: 448x640 2 persons, 1 motorcycle, 191.8ms
# Speed: 2.0ms preprocess, 191.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\helmet5.jpg
# Processing image: downloaded_images\non_violation\helmet7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet7.jpg: 448x640 2 with helmets, 166.5ms
# Speed: 3.0ms preprocess, 166.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\helmet7.jpg: 448x640 2 persons, 1 motorcycle, 2 trucks, 174.5ms
# Speed: 3.0ms preprocess, 174.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\helmet7.jpg
# Processing image: downloaded_images\non_violation\images (10).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (10).jpg: 448x640 1 with helmet, 153.8ms
# Speed: 2.0ms preprocess, 153.8ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (10).jpg: 448x640 1 person, 162.9ms
# Speed: 2.1ms preprocess, 162.9ms inference, 3.1ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\images (10).jpg
# Processing image: downloaded_images\non_violation\images (5).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (5).jpg: 448x640 1 with helmet, 156.9ms
# Speed: 2.0ms preprocess, 156.9ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (5).jpg: 448x640 3 persons, 1 motorcycle, 162.2ms
# Speed: 2.1ms preprocess, 162.2ms inference, 3.1ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\images (5).jpg
# Processing image: downloaded_images\non_violation\images (6).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (6).jpg: 448x640 1 with helmet, 152.1ms
# Speed: 3.0ms preprocess, 152.1ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (6).jpg: 448x640 2 persons, 1 motorcycle, 172.0ms
# Speed: 2.1ms preprocess, 172.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\images (6).jpg
# Processing image: downloaded_images\non_violation\images (7).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (7).jpg: 384x640 2 with helmets, 133.7ms
# Speed: 2.0ms preprocess, 133.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\images (7).jpg: 384x640 2 persons, 1 baseball glove, 140.8ms
# Speed: 1.0ms preprocess, 140.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\images (7).jpg
# Processing image: downloaded_images\non_violation\Image_02_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_02_Vishal_Pal.jpg: 640x448 1 with helmet, 154.8ms
# Speed: 3.2ms preprocess, 154.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_02_Vishal_Pal.jpg: 640x448 3 persons, 1 motorcycle, 171.2ms
# Speed: 3.0ms preprocess, 171.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 448)
# Saved detected objects image: output_images_combined\Image_02_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_03_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_03_Vishal_Pal.jpg: 512x640 1 with helmet, 198.9ms
# Speed: 2.0ms preprocess, 198.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_03_Vishal_Pal.jpg: 512x640 3 persons, 1 motorcycle, 188.4ms
# Speed: 2.0ms preprocess, 188.4ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected objects image: output_images_combined\Image_03_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_06_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_06_Vishal_Pal.jpg: 384x640 1 with helmet, 128.6ms
# Speed: 2.0ms preprocess, 128.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_06_Vishal_Pal.jpg: 384x640 1 person, 1 car, 1 motorcycle, 1 truck, 218.7ms
# Speed: 2.0ms preprocess, 218.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\Image_06_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\Image_08_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_08_Vishal_Pal.jpg: 448x640 2 with helmets, 151.8ms
# Speed: 2.0ms preprocess, 151.8ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\Image_08_Vishal_Pal.jpg: 448x640 2 persons, 2 motorcycles, 163.8ms
# Speed: 2.0ms preprocess, 163.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\Image_08_Vishal_Pal.jpg
# Processing image: downloaded_images\non_violation\n.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\n.jpeg: 480x640 2 without helmets, 1 with helmet, 168.8ms
# Speed: 1.8ms preprocess, 168.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\n.jpeg: 480x640 2 persons, 1 motorcycle, 3 backpacks, 183.5ms
# Speed: 2.1ms preprocess, 183.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\n.jpeg
# Processing image: downloaded_images\non_violation\n4.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\n4.jpeg: 640x480 (no detections), 171.5ms
# Speed: 4.0ms preprocess, 171.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\n4.jpeg: 640x480 1 person, 1 car, 2 motorcycles, 173.6ms
# Speed: 2.0ms preprocess, 173.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Saved detected objects image: output_images_combined\n4.jpeg
# Processing image: downloaded_images\non_violation\nonviolation_10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_10.jpg: 448x640 1 with helmet, 141.4ms
# Speed: 2.0ms preprocess, 141.4ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_10.jpg: 448x640 1 person, 1 motorcycle, 170.5ms
# Speed: 2.6ms preprocess, 170.5ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\nonviolation_10.jpg
# Processing image: downloaded_images\non_violation\nonviolation_2.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_2.png: 480x640 1 with helmet, 165.5ms
# Speed: 3.0ms preprocess, 165.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_2.png: 480x640 1 person, 1 motorcycle, 178.0ms
# Speed: 2.1ms preprocess, 178.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\nonviolation_2.png
# Processing image: downloaded_images\non_violation\nonviolation_3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_3.jpg: 544x640 2 with helmets, 181.7ms
# Speed: 4.0ms preprocess, 181.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_3.jpg: 544x640 3 persons, 1 motorcycle, 201.1ms
# Speed: 3.1ms preprocess, 201.1ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
# Saved detected objects image: output_images_combined\nonviolation_3.jpg
# Processing image: downloaded_images\non_violation\nonviolation_4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_4.jpg: 640x512 1 with helmet, 183.7ms
# Speed: 2.0ms preprocess, 183.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_4.jpg: 640x512 1 person, 1 motorcycle, 186.9ms
# Speed: 2.8ms preprocess, 186.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
# Saved detected objects image: output_images_combined\nonviolation_4.jpg
# Processing image: downloaded_images\non_violation\nonviolation_5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_5.jpg: 544x640 1 with helmet, 189.5ms
# Speed: 5.0ms preprocess, 189.5ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_5.jpg: 544x640 2 persons, 202.7ms
# Speed: 3.0ms preprocess, 202.7ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
# Saved detected objects image: output_images_combined\nonviolation_5.jpg
# Processing image: downloaded_images\non_violation\nonviolation_6.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_6.jpg: 448x640 1 with helmet, 153.4ms
# Speed: 2.0ms preprocess, 153.4ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nonviolation_6.jpg: 448x640 1 person, 1 motorcycle, 172.0ms
# Speed: 2.4ms preprocess, 172.0ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\nonviolation_6.jpg
# Processing image: downloaded_images\non_violation\nv1.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nv1.jpeg: 384x640 2 with helmets, 136.4ms
# Speed: 3.0ms preprocess, 136.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\nv1.jpeg: 384x640 4 persons, 1 motorcycle, 152.1ms
# Speed: 2.1ms preprocess, 152.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\nv1.jpeg
# Processing image: downloaded_images\non_violation\pillion-rider.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\pillion-rider.jpg: 448x640 2 with helmets, 174.2ms
# Speed: 3.0ms preprocess, 174.2ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\pillion-rider.jpg: 448x640 3 persons, 1 car, 1 motorcycle, 189.8ms
# Speed: 3.0ms preprocess, 189.8ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\pillion-rider.jpg
# Processing image: downloaded_images\non_violation\s1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\s1.jpg: 480x640 2 with helmets, 196.6ms
# Speed: 3.0ms preprocess, 196.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\s1.jpg: 480x640 2 persons, 1 motorcycle, 227.2ms
# Speed: 3.0ms preprocess, 227.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\s1.jpg
# Processing image: downloaded_images\non_violation\s2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\s2.jpg: 384x640 2 with helmets, 152.0ms
# Speed: 2.0ms preprocess, 152.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\non_violation\s2.jpg: 384x640 2 persons, 2 backpacks, 1 sports ball, 164.9ms
# Speed: 2.0ms preprocess, 164.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\s2.jpg
# Processing directory: downloaded_images\violation
# Files in directory (43 items): ['100407182.webp', '2.jpg', '3.jpg', '3.png', '3007806.JPG', '65826504.jpg', '7.jpg', '7.jpg.jpeg', '8 (1).jpg', '8.jpg', '8.jpg.jpeg', 'boymg0f7zs1b1.jpg', 'image 10.jpeg', 'image5.jpg', 'images (1).jpeg', 'images.jpeg', 'Image_03_Vishal_Pal.jpg', 'Image_07_Vishal_Pal.jpg', 'Image_09_Vishal_Pal.jpg', 'Non helmet.1.jpg', 'Non helmet.9.jpg', 'v10.jpg', 'v11.jpg', 'v12.jpg', 'v13.jpg', 'v14.jpg', 'v15.jpg', 'v16.jpg', 'v17.jpg', 'v3.jpeg', 'v3.jpg', 'v4.jpg', 'v5.jpg', 'v6.jpg', 'v7.jpg', 'v8.jpg', 'v9.jpg', 'violation5.jpg', 'violation8.jpg', 'violation_1.jpg', 'violation_2.jpg', 'violation_3.jpg', 'vio_4.jpg']
# Processing image: downloaded_images\violation\100407182.webp
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\100407182.webp: 384x640 2 with helmets, 145.8ms
# Speed: 2.0ms preprocess, 145.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\100407182.webp: 384x640 8 persons, 5 cars, 3 motorcycles, 169.2ms
# Speed: 3.0ms preprocess, 169.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\100407182.webp
# Processing image: downloaded_images\violation\2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\2.jpg: 416x640 3 without helmets, 155.6ms
# Speed: 3.0ms preprocess, 155.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\2.jpg: 416x640 7 persons, 2 motorcycles, 189.0ms
# Speed: 3.0ms preprocess, 189.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected objects image: output_images_combined\2.jpg
# Processing image: downloaded_images\violation\3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3.jpg: 384x640 1 without helmet, 153.0ms
# Speed: 2.0ms preprocess, 153.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3.jpg: 384x640 1 person, 1 motorcycle, 186.7ms
# Speed: 2.0ms preprocess, 186.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\3.jpg
# Processing image: downloaded_images\violation\3.png
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3.png: 352x640 1 without helmet, 1 with helmet, 138.1ms
# Speed: 2.0ms preprocess, 138.1ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3.png: 352x640 2 persons, 1 motorcycle, 155.4ms
# Speed: 1.0ms preprocess, 155.4ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
# Saved detected objects image: output_images_combined\3.png
# Processing image: downloaded_images\violation\3007806.JPG
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3007806.JPG: 448x640 1 without helmet, 1 with helmet, 158.5ms
# Speed: 2.0ms preprocess, 158.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\3007806.JPG: 448x640 5 persons, 1 motorcycle, 260.2ms
# Speed: 2.0ms preprocess, 260.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\3007806.JPG
# Processing image: downloaded_images\violation\65826504.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\65826504.jpg: 480x640 3 without helmets, 179.7ms
# Speed: 4.0ms preprocess, 179.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\65826504.jpg: 480x640 5 persons, 200.1ms
# Speed: 3.0ms preprocess, 200.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\65826504.jpg
# Processing image: downloaded_images\violation\7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\7.jpg: 480x640 2 without helmets, 1 with helmet, 192.5ms
# Speed: 2.5ms preprocess, 192.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\7.jpg: 480x640 5 persons, 1 motorcycle, 1 handbag, 212.2ms
# Speed: 3.0ms preprocess, 212.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\7.jpg
# Processing image: downloaded_images\violation\7.jpg.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\7.jpg.jpeg: 480x640 5 without helmets, 183.3ms
# Speed: 3.0ms preprocess, 183.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\7.jpg.jpeg: 480x640 5 persons, 1 motorcycle, 192.2ms
# Speed: 2.0ms preprocess, 192.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\7.jpg.jpeg
# Processing image: downloaded_images\violation\8 (1).jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8 (1).jpg: 480x640 2 without helmets, 2 with helmets, 198.1ms
# Speed: 3.0ms preprocess, 198.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8 (1).jpg: 480x640 5 persons, 1 car, 1 backpack, 1 handbag, 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\8 (1).jpg
# Processing image: downloaded_images\violation\8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8.jpg: 480x640 2 without helmets, 187.2ms
# Speed: 3.0ms preprocess, 187.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8.jpg: 480x640 2 persons, 1 motorcycle, 1 truck, 197.4ms
# Speed: 2.0ms preprocess, 197.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\8.jpg
# Processing image: downloaded_images\violation\8.jpg.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8.jpg.jpeg: 480x640 2 without helmets, 174.7ms
# Speed: 3.0ms preprocess, 174.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\8.jpg.jpeg: 480x640 2 persons, 1 car, 2 motorcycles, 210.5ms
# Speed: 3.0ms preprocess, 210.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\8.jpg.jpeg
# Processing image: downloaded_images\violation\boymg0f7zs1b1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\boymg0f7zs1b1.jpg: 448x640 1 without helmet, 1 with helmet, 161.6ms
# Speed: 3.0ms preprocess, 161.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\boymg0f7zs1b1.jpg: 448x640 3 persons, 1 motorcycle, 1 sports ball, 170.0ms
# Speed: 2.0ms preprocess, 170.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\boymg0f7zs1b1.jpg
# Processing image: downloaded_images\violation\image 10.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\image 10.jpeg: 352x640 2 without helmets, 129.4ms
# Speed: 2.0ms preprocess, 129.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\image 10.jpeg: 352x640 3 persons, 3 cars, 1 motorcycle, 1 bus, 1 truck, 134.8ms
# Speed: 3.0ms preprocess, 134.8ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
# Saved detected objects image: output_images_combined\image 10.jpeg
# Processing image: downloaded_images\violation\image5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\image5.jpg: 448x640 2 without helmets, 176.8ms
# Speed: 3.0ms preprocess, 176.8ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\image5.jpg: 448x640 1 person, 1 motorcycle, 1 backpack, 187.5ms
# Speed: 3.0ms preprocess, 187.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved detected objects image: output_images_combined\image5.jpg
# Processing image: downloaded_images\violation\images (1).jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\images (1).jpeg: 384x640 2 without helmets, 154.2ms
# Speed: 2.0ms preprocess, 154.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\images (1).jpeg: 384x640 6 persons, 1 motorcycle, 167.9ms
# Speed: 1.1ms preprocess, 167.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\images (1).jpeg
# Processing image: downloaded_images\violation\images.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\images.jpeg: 544x640 3 without helmets, 202.2ms
# Speed: 5.0ms preprocess, 202.2ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\images.jpeg: 544x640 6 persons, 2 cars, 1 motorcycle, 1 bus, 213.2ms
# Speed: 3.0ms preprocess, 213.2ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
# Saved detected objects image: output_images_combined\images.jpeg
# Processing image: downloaded_images\violation\Image_03_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Image_03_Vishal_Pal.jpg: 512x640 1 without helmet, 1 with helmet, 177.4ms
# Speed: 3.1ms preprocess, 177.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Image_03_Vishal_Pal.jpg: 512x640 5 persons, 1 motorcycle, 220.2ms
# Speed: 3.0ms preprocess, 220.2ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected objects image: output_images_combined\Image_03_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Image_07_Vishal_Pal.jpg
# Failed to load image (cv2.imread returned None): Image_07_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Image_09_Vishal_Pal.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Image_09_Vishal_Pal.jpg: 640x320 1 without helmet, 123.5ms
# Speed: 1.0ms preprocess, 123.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Image_09_Vishal_Pal.jpg: 640x320 3 persons, 2 motorcycles, 1 potted plant, 140.6ms
# Speed: 4.0ms preprocess, 140.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 320)
# Saved detected objects image: output_images_combined\Image_09_Vishal_Pal.jpg
# Processing image: downloaded_images\violation\Non helmet.1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Non helmet.1.jpg: 416x640 2 without helmets, 144.4ms
# Speed: 2.1ms preprocess, 144.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Non helmet.1.jpg: 416x640 2 persons, 2 cars, 1 motorcycle, 1 bus, 2 trucks, 160.9ms
# Speed: 3.4ms preprocess, 160.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected objects image: output_images_combined\Non helmet.1.jpg
# Processing image: downloaded_images\violation\Non helmet.9.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Non helmet.9.jpg: 640x288 2 without helmets, 100.9ms
# Speed: 2.0ms preprocess, 100.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\Non helmet.9.jpg: 640x288 2 persons, 1 motorcycle, 125.8ms
# Speed: 1.0ms preprocess, 125.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 288)
# Saved detected objects image: output_images_combined\Non helmet.9.jpg
# Processing image: downloaded_images\violation\v10.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v10.jpg: 640x640 1 with helmet, 205.1ms
# Speed: 3.0ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v10.jpg: 640x640 3 persons, 1 motorcycle, 233.3ms
# Speed: 3.0ms preprocess, 233.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected objects image: output_images_combined\v10.jpg
# Processing image: downloaded_images\violation\v11.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v11.jpg: 640x640 3 without helmets, 220.2ms
# Speed: 12.1ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v11.jpg: 640x640 4 persons, 3 motorcycles, 1 handbag, 236.7ms
# Speed: 12.2ms preprocess, 236.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected objects image: output_images_combined\v11.jpg
# Processing image: downloaded_images\violation\v12.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v12.jpg: 640x640 2 with helmets, 307.4ms
# Speed: 4.3ms preprocess, 307.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v12.jpg: 640x640 2 persons, 1 motorcycle, 233.0ms
# Speed: 4.0ms preprocess, 233.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected objects image: output_images_combined\v12.jpg
# Processing image: downloaded_images\violation\v13.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v13.jpg: 352x640 3 without helmets, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v13.jpg: 352x640 6 persons, 1 motorcycle, 1 truck, 133.4ms
# Speed: 2.0ms preprocess, 133.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
# Saved detected objects image: output_images_combined\v13.jpg
# Processing image: downloaded_images\violation\v14.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v14.jpg: 480x640 3 without helmets, 169.1ms
# Speed: 2.9ms preprocess, 169.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v14.jpg: 480x640 5 persons, 1 motorcycle, 1 umbrella, 171.4ms
# Speed: 2.0ms preprocess, 171.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\v14.jpg
# Processing image: downloaded_images\violation\v15.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v15.jpg: 640x640 2 with helmets, 209.2ms
# Speed: 2.9ms preprocess, 209.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v15.jpg: 640x640 6 persons, 2 motorcycles, 229.3ms
# Speed: 3.0ms preprocess, 229.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected objects image: output_images_combined\v15.jpg
# Processing image: downloaded_images\violation\v16.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v16.jpg: 640x640 3 without helmets, 213.7ms
# Speed: 4.5ms preprocess, 213.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v16.jpg: 640x640 5 persons, 1 motorcycle, 242.7ms
# Speed: 4.0ms preprocess, 242.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected objects image: output_images_combined\v16.jpg
# Processing image: downloaded_images\violation\v17.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v17.jpg: 480x640 3 without helmets, 1 with helmet, 161.4ms
# Speed: 3.0ms preprocess, 161.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v17.jpg: 480x640 4 persons, 1 motorcycle, 187.9ms
# Speed: 4.0ms preprocess, 187.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\v17.jpg
# Processing image: downloaded_images\violation\v3.jpeg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v3.jpeg: 416x640 2 without helmets, 144.4ms
# Speed: 2.0ms preprocess, 144.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v3.jpeg: 416x640 3 persons, 3 motorcycles, 160.4ms
# Speed: 2.0ms preprocess, 160.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected objects image: output_images_combined\v3.jpeg
# Processing image: downloaded_images\violation\v3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v3.jpg: 640x544 2 without helmets, 183.7ms
# Speed: 3.0ms preprocess, 183.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v3.jpg: 640x544 2 persons, 202.8ms
# Speed: 3.0ms preprocess, 202.8ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 544)
# Saved detected objects image: output_images_combined\v3.jpg
# Processing image: downloaded_images\violation\v4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v4.jpg: 384x640 1 without helmet, 2 with helmets, 127.2ms
# Speed: 15.0ms preprocess, 127.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v4.jpg: 384x640 3 persons, 2 cars, 2 motorcycles, 144.9ms
# Speed: 2.2ms preprocess, 144.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\v4.jpg
# Processing image: downloaded_images\violation\v5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v5.jpg: 480x640 2 without helmets, 169.6ms
# Speed: 5.1ms preprocess, 169.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v5.jpg: 480x640 3 persons, 1 car, 1 motorcycle, 1 potted plant, 175.5ms
# Speed: 9.0ms preprocess, 175.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\v5.jpg
# Processing image: downloaded_images\violation\v6.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v6.jpg: 544x640 3 without helmets, 180.6ms
# Speed: 10.1ms preprocess, 180.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v6.jpg: 544x640 3 persons, 1 motorcycle, 1 handbag, 195.4ms
# Speed: 8.0ms preprocess, 195.4ms inference, 2.9ms postprocess per image at shape (1, 3, 544, 640)
# Saved detected objects image: output_images_combined\v6.jpg
# Processing image: downloaded_images\violation\v7.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v7.jpg: 640x640 1 with helmet, 218.3ms
# Speed: 3.0ms preprocess, 218.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v7.jpg: 640x640 2 persons, 241.1ms
# Speed: 3.1ms preprocess, 241.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved detected objects image: output_images_combined\v7.jpg
# Processing image: downloaded_images\violation\v8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v8.jpg: 480x640 2 without helmets, 1 with helmet, 161.9ms
# Speed: 3.0ms preprocess, 161.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v8.jpg: 480x640 2 persons, 1 motorcycle, 171.3ms
# Speed: 4.0ms preprocess, 171.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\v8.jpg
# Processing image: downloaded_images\violation\v9.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v9.jpg: 480x640 3 without helmets, 168.8ms
# Speed: 2.9ms preprocess, 168.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\v9.jpg: 480x640 3 persons, 1 motorcycle, 1 backpack, 1 handbag, 209.0ms
# Speed: 2.0ms preprocess, 209.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\v9.jpg
# Processing image: downloaded_images\violation\violation5.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation5.jpg: 480x640 3 without helmets, 172.8ms
# Speed: 2.0ms preprocess, 172.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation5.jpg: 480x640 3 persons, 1 motorcycle, 220.6ms
# Speed: 3.0ms preprocess, 220.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\violation5.jpg
# Processing image: downloaded_images\violation\violation8.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation8.jpg: 384x640 2 without helmets, 160.9ms
# Speed: 2.0ms preprocess, 160.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation8.jpg: 384x640 3 persons, 147.3ms
# Speed: 2.0ms preprocess, 147.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\violation8.jpg
# Processing image: downloaded_images\violation\violation_1.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_1.jpg: 480x640 1 without helmet, 164.7ms
# Speed: 2.0ms preprocess, 164.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_1.jpg: 480x640 1 person, 1 motorcycle, 172.0ms
# Speed: 1.8ms preprocess, 172.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved detected objects image: output_images_combined\violation_1.jpg
# Processing image: downloaded_images\violation\violation_2.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_2.jpg: 384x640 1 without helmet, 132.7ms
# Speed: 1.9ms preprocess, 132.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_2.jpg: 384x640 4 persons, 1 car, 1 motorcycle, 140.3ms
# Speed: 2.9ms preprocess, 140.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved detected objects image: output_images_combined\violation_2.jpg
# Processing image: downloaded_images\violation\violation_3.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_3.jpg: 416x640 1 without helmet, 1 with helmet, 143.4ms
# Speed: 2.0ms preprocess, 143.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\violation_3.jpg: 416x640 3 persons, 2 motorcycles, 168.1ms
# Speed: 2.0ms preprocess, 168.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved detected objects image: output_images_combined\violation_3.jpg
# Processing image: downloaded_images\violation\vio_4.jpg
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\vio_4.jpg: 512x640 3 without helmets, 194.2ms
# Speed: 3.0ms preprocess, 194.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\downloaded_images\violation\vio_4.jpg: 512x640 8 persons, 1 motorcycle, 181.3ms
# Speed: 2.0ms preprocess, 181.3ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved detected objects image: output_images_combined\vio_4.jpg

# %%
cd nanonets-ocr-sample-python
# Out:
# c:\Users\Arshia Shaikh\BIKEASTECH\BIKEHELMET\nanonets-ocr-sample-python

# %%
pip install requests tqdm
# Out:
# Requirement already satisfied: requests in c:\users\arshia shaikh\.conda\envs\helmet_detection\lib\site-packages (2.32.2)
# Requirement already satisfied: tqdm in c:\users\arshia shaikh\.conda\envs\helmet_detection\lib\site-packages (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arshia shaikh\.conda\envs\helmet_detection\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arshia shaikh\.conda\envs\helmet_detection\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arshia shaikh\.conda\envs\helmet_detection\lib\site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arshia shaikh\.conda\envs\helmet_detection\lib\site-packages (from requests) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\arshia shaikh\.conda\envs\helmet_detection\lib\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Set the environment variable
os.environ['NANONETS_API_KEY'] = 'api'

# Now you can continue with your script
import requests
import json

url = "https://app.nanonets.com/api/v2/ObjectDetection/Model/"
api_key = os.getenv('NANONETS_API_KEY')

payload = json.dumps({"categories": ["number_plate"], "model_type": "ocr"})
headers = {'Content-Type': "application/json"}

response = requests.post(url, headers=headers, auth=requests.auth.HTTPBasicAuth(api_key, ''), data=payload)

# Check if the request was successful
if response.status_code == 200:
    try:
        # Try to extract the model_id from the response
        response_json = response.json()
        model_id = response_json["model_id"]
        print("NEXT RUN: export NANONETS_MODEL_ID=" + model_id)
        print("THEN RUN: python ./code/upload-training.py")
    except KeyError:
        print("Error: 'model_id' not found in the response JSON")
        print("Response JSON:", response_json)
    except json.JSONDecodeError:
        print("Error: Failed to decode JSON from response")
else:
    print(f"Error: API request failed with status code {response.status_code}")
# Out:
# Error: API request failed with status code 500

# %%
import os

os.environ['NANONETS_MODEL_ID'] = 'api'

# %%
# !python ./code/upload-training.py
# Out:
#   0%|          | 0/324 [00:00<?, ?it/s]
#   0%|          | 1/324 [00:01<09:23,  1.74s/it]
#   1%|          | 2/324 [00:03<08:06,  1.51s/it]
#   1%|          | 3/324 [00:04<07:48,  1.46s/it]
#   1%|          | 3/324 [00:04<08:00,  1.50s/it]
# Traceback (most recent call last):
#   File "./code/upload-training.py", line 19, in <module>
#     data = {'file' :open(imagePath, 'rb'),  'data' :('', '[{"filename":"' + imageName+".jpg" + '", "object": '+ jsonData+'}]'),   'modelId' :('', model_id)}
# FileNotFoundError: [Errno 2] No such file or directory: './images\\100.jpg'

# %%
# !python ./code/train-model.py
# Out:
# {"model_id":"faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0","model_type":"ocr","state":6,"status":"Retraining in progress","accuracy":94.583336,"categories":[{"name":"number_plate","count":200,"id":"d593f7f6-74a7-40a6-9ff0-d0e3e6bf0b8f","routing":"","currently_renaming":false,"description":"","edit_restricted":false}],"email":"","is_public":false,"table_categories":[{"label":"","headers":[],"headers_count":{},"id_info":{},"headers_being_renamed":{},"header_descriptions":{},"restricted_ids":null}],"metadata":{"cropped_rotated_experiment_metadata":null,"use_cropped_rotated_experiment":false,"parent_model_id":"","is_cropped_rotated_dataset_dirty":true,"custom_model_name":"","custom_model_response_type":"","extract_tables":true,"map_invoice_line_items":false,"show_crop_images_on_rhs":false,"entire_page_text":false,"document_level_search":false,"table_categories":[{"label":"","headers":[],"headers_count":{},"id_info":{},"headers_being_renamed":{},"header_descriptions":{},"restricted_ids":null}],"feature_flags":null,"gcn_override_config":"","export_info":{"is_export_enabled_on_inference":false,"is_export_enabled_on_verification":false,"is_export_enabled_on_rejection":false,"is_export_enabled_on_passing_all_review_stages":false,"is_export_enabled_on_stage_change":false,"export_stage_ids":null,"is_export_enabled_on_assignment":false,"has_been_requested":false,"action":"","integration_id":"","field_mapping":null,"export_metadata":{"table_name":"","script_content":"","organization":"","use_unlabelled_table_headers":false,"file_name_settings":{"rename_type":"","dynamic_rename_config":{"fields":null}},"doc_level_result":false},"name":"","type":"","is_doc_level_export_enabled":false,"export_id":"","conditional_config":{"conditions":null,"setting":{"processing_type":"","operation_type":""}},"export_category":"","generic_block_info":{"block_type":"","id":"","prev_step_id":"","authentication_type":"","oauth_info":{"active":false,"service":"","authentication_url":"","vendor_name":""},"account_name":"","input_info":{"params":null,"current_index":0,"params_final":false,"validations":{},"processing_type":"","selection_type":""},"conditional_config":{"conditions":null,"setting":{"processing_type":"","operation_type":""}},"is_export":false,"export_info":{"is_export_enabled_on_inference":false,"is_export_enabled_on_verification":false,"is_export_enabled_on_passing_all_review_stages":false,"is_export_enabled_on_stage_change":false,"is_export_enabled_on_assignment":false,"export_stage_ids":null,"is_doc_level_export_enabled":false,"has_been_requested":false,"action":""}},"export_header_name":""},"storage_permission":"","light_experiments":false,"box_in_box_table":false,"captured_data_view":{"is_set":false,"file_info":null,"fields":null,"options":null},"append_from_email_to_file":false,"process_email_with_no_attachment":false,"store_email_data_in_inference":false,"on_retrain_only_hosted_exp":"","upload_image_to_s3_sync":false,"show_empty_prediction":false,"show_empty_prediction_threshold":0,"file_rename_config":{"fields":null},"bulk_async_threshold":0,"tables_found":false,"invoice_line_item_model_version":0,"override_async_queue":"","disable_sync_limit_throttling":false,"use_translate":false,"use_maps":false,"use_openai":false,"usage_soft_threshold_for_stripe":0,"stripe_soft_threshold_info":{"payment_failed":false,"cycle_start_date":"0001-01-01T00:00:00Z","soft_threshold_value":0,"charged_on":"0001-01-01T00:00:00Z","charged_for_usage":0,"payment_failure_error":null,"charge_id":""},"min_email_upload_size":0,"file_types_not_allowed":null,"zero_shot_fallback":false,"one_shot_prompt_info":{"about_document":"","extract_values":"","format_response":"","sample_documents":"","no_of_sample_documents":"","space_width_multiplier":"","tab_width_multiplier":"","remove_leading_spaces_percentile":"","layout_aware_text":false,"oneshot_match_threshold":0,"add_all_extracted_keys":false,"mobile_net_v2_enabled":false,"mobile_net_v2_weight":0,"add_line_number":false,"extract_columns ...
#
#
# NEXT RUN: python ./code/model-state.py

# %%
# !python ./code/model-state.py
# Out:
# The model isn't ready yet, its status is: Retraining in progress
# We will send you an email when the model is ready. If you are impatient, run this script again in 10 minutes to check.

# %%
# !python ./code/model-state.py
# Out:
# The model isn't ready yet, its status is: Retraining in progress
# We will send you an email when the model is ready. If you are impatient, run this script again in 10 minutes to check.

# %%
# !python ./code/prediction.py ./images/v10.jpg
# Out:
# {"message":"Success","result":[{"message":"Success","input":"v10.jpg","prediction":[{"id":"529bbabe-05e1-45c9-818d-d3ec41d9ff4a","label":"number_plate","xmin":551,"ymin":793,"xmax":671,"ymax":846,"score":0,"ocr_text":"JHOIBT\n5262","type":"field","status":"correctly_predicted","page_no":0,"label_id":"d593f7f6-74a7-40a6-9ff0-d0e3e6bf0b8f","lookup_edited":false,"lookup_parent_id":""}],"page":0,"request_file_id":"6e39ca5e-2c23-4e44-97b1-cd98559e1088","filepath":"uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/PredictionImages/745a5e87-b4ec-4fda-8985-f9f746a166aa.jpeg","id":"0c357bab-32ee-11ef-be12-46dd1ae503a2","rotation":0,"file_url":"uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/RawPredictions/6e39ca5e-2c23-4e44-97b1-cd98559e1088.jpg","request_metadata":"","processing_type":"sync","size":{"width":918,"height":1428},"raw_ocr_api_response":{"results":null}}],"signed_urls":{"uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/PredictionImages/745a5e87-b4ec-4fda-8985-f9f746a166aa.jpeg":{"original":"https://ik.imagekit.io/nanonets/tr:rt-0,true/uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/PredictionImages/745a5e87-b4ec-4fda-8985-f9f746a166aa.jpeg?ik-s=38a4b5e4d8423e3d5d77866c8ae5d4a8190d5faa\u0026ik-t=1719332758","original_compressed":"https://ik.imagekit.io/nanonets/tr:rt-0/uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/PredictionImages/745a5e87-b4ec-4fda-8985-f9f746a166aa.jpeg?ik-s=12f582a903a02f3b691aba0db85864df4d0d5543\u0026ik-t=1719332758","thumbnail":"https://ik.imagekit.io/nanonets/tr:w-240/uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/PredictionImages/745a5e87-b4ec-4fda-8985-f9f746a166aa.jpeg?ik-s=25425fe992c7f318a9af7342cf14940c0ba8baac\u0026ik-t=1719332758","acw_rotate_90":"https://ik.imagekit.io/nanonets/tr:rt-270/uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/PredictionImages/745a5e87-b4ec-4fda-8985-f9f746a166aa.jpeg?ik-s=5ff10f8de5b2007304c3b32ae363410297b1a738\u0026ik-t=1719332758","acw_rotate_180":"https://ik.imagekit.io/nanonets/tr:rt-180/uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/PredictionImages/745a5e87-b4ec-4fda-8985-f9f746a166aa.jpeg?ik-s=5485784c7433f74df107db8a3adad0f7ce3ba995\u0026ik-t=1719332758","acw_rotate_270":"https://ik.imagekit.io/nanonets/tr:rt-90/uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/PredictionImages/745a5e87-b4ec-4fda-8985-f9f746a166aa.jpeg?ik-s=cd6f9401e351fe2b4c3862b8780420647e7dd63e\u0026ik-t=1719332758","original_with_long_expiry":"https://ik.imagekit.io/nanonets/tr:rt-0/uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/PredictionImages/745a5e87-b4ec-4fda-8985-f9f746a166aa.jpeg?ik-s=43e05cf3ccd4c9352c82e6e49ac6af54d7d5813c\u0026ik-t=1734870358"},"uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/RawPredictions/6e39ca5e-2c23-4e44-97b1-cd98559e1088.jpg":{"original":"https://nanonets.s3.us-west-2.amazonaws.com/uploadedfiles/faa1f6d2-2b95-4378-ad28-b7fe0edfa7a0/RawPredictions/6e39ca5e-2c23-4e44-97b1-cd98559e1088.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256\u0026X-Amz-Credential=AKIA5F4WPNNTLX3QHN4W%2F20240625%2Fus-west-2%2Fs3%2Faws4_request\u0026X-Amz-Date=20240625T122558Z\u0026X-Amz-Expires=604800\u0026X-Amz-SignedHeaders=host\u0026response-cache-control=no-cache\u0026X-Amz-Signature=a1d6a3935f958c7b5fb8993e03700e521c38cd61b640503fc60024bb0ee4eaf5","original_compressed":"","thumbnail":"","acw_rotate_90":"","acw_rotate_180":"","acw_rotate_270":"","original_with_long_expiry":""}}}

# %%
pip install psycopg2-binary smtplib email
# Out:
# Collecting psycopg2-binary
#   Using cached psycopg2_binary-2.9.9-cp38-cp38-win_amd64.whl.metadata (4.5 kB)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement smtplib (from versions: none)
# ERROR: No matching distribution found for smtplib
