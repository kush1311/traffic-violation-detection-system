# %%
import boto3
import os
from botocore.exceptions import NoCredentialsError, PartialCredentialsError

# %% [markdown]
# **env Variables**

# %%
bucket_name = 'bikewatch'
violation_folder = 'Violation-Images'
nonviolation_folder = 'Nonviolation-Images'

# %%
def list_bucket_contents(bucket_name):
    """
    List the contents of an S3 bucket
    
    :param bucket_name: The name of the S3 bucket
    """
    s3_client = boto3.client('s3')
    
    try:
        response = s3_client.list_objects_v2(Bucket=bucket_name)
        if 'Contents' in response:
            print(f"Contents of bucket '{bucket_name}':")
            for obj in response['Contents']:
                print(f" - {obj['Key']} (Last modified: {obj['LastModified']}, Size: {obj['Size']} bytes)")
        else:
            print(f"The bucket '{bucket_name}' is empty.")
    
    except NoCredentialsError:
        print('Credentials not available.')
    except PartialCredentialsError:
        print('Incomplete credentials provided.')
    except Exception as e:
        print(f'An error occurred: {e}')


list_bucket_contents(bucket_name)
# Out:
# Contents of bucket 'bikewatch':
#  - Best-cricket-players-2024-283d079.jpg (Last modified: 2024-05-31 05:51:15+00:00, Size: 117000 bytes)
#  - Nonviolation-Images/ (Last modified: 2024-06-06 12:58:59+00:00, Size: 0 bytes)
#  - Nonviolation-Images/033_213_jpeg_jpg.rf.4b5d3b7bc83a1c4105414810b1df6cb2.jpg (Last modified: 2024-06-06 14:15:06+00:00, Size: 62859 bytes)
#  - Nonviolation-Images/098-Rhythm138_jpg.rf.bc96b0107d969835b65336ac2a20aa4f.jpg (Last modified: 2024-06-06 14:15:07+00:00, Size: 86278 bytes)
#  - Nonviolation-Images/098-Rhythm27_jpg.rf.2fe69cafedb41b3450f32035701f918a.jpg (Last modified: 2024-06-06 14:15:08+00:00, Size: 95028 bytes)
#  - Nonviolation-Images/098-Rhythm46_jpg.rf.76b884ee943b191e0f25bae5c5afbb07.jpg (Last modified: 2024-06-06 14:15:08+00:00, Size: 99629 bytes)
#  - Nonviolation-Images/098_272_jpg.rf.e87ecbcf0d95642ef4cc7b05da422144.jpg (Last modified: 2024-06-06 14:15:09+00:00, Size: 70941 bytes)
#  - Nonviolation-Images/1.jpg (Last modified: 2024-06-06 16:31:58+00:00, Size: 21176 bytes)
#  - Nonviolation-Images/10.jpg (Last modified: 2024-06-06 16:31:58+00:00, Size: 46870 bytes)
#  - Nonviolation-Images/11.jpg (Last modified: 2024-06-06 14:43:00+00:00, Size: 10155 bytes)
#  - Nonviolation-Images/12.jpg (Last modified: 2024-06-06 14:43:00+00:00, Size: 17346 bytes)
#  - Nonviolation-Images/2.jpg (Last modified: 2024-06-06 16:31:58+00:00, Size: 16992 bytes)
#  - Nonviolation-Images/3.jpg (Last modified: 2024-06-06 16:31:58+00:00, Size: 97399 bytes)
#  - Nonviolation-Images/4.jpg (Last modified: 2024-06-06 16:31:58+00:00, Size: 62788 bytes)
#  - Nonviolation-Images/5.jpg (Last modified: 2024-06-06 16:31:58+00:00, Size: 116197 bytes)
#  - Nonviolation-Images/6.jpg (Last modified: 2024-06-06 16:31:58+00:00, Size: 143513 bytes)
#  - Nonviolation-Images/7.jpg (Last modified: 2024-06-06 16:31:58+00:00, Size: 89512 bytes)
#  - Nonviolation-Images/8.jpg (Last modified: 2024-06-06 16:31:58+00:00, Size: 18686 bytes)
#  - Violation-Images/samut-prakan-thailand-june-30-2020-a-group-of-people-ride-on-a-motorbike-2DA9W0B_jpg.rf.47c68a7a6bdb188fca68b41ba2d06e49.jpg (Last modified: 2024-06-06 14:15:03+00:00, Size: 51094 bytes)
#  - Violation-Images/samut-prakan-thailand-may-29-2022-a-boy-drives-a-motorcycle-with-two-women-2K1P052_jpg.rf.5a941c25c400aba6e83dfbaaddb75ea0.jpg (Last modified: 2024-06-06 14:15:03+00:00, Size: 54554 bytes)
#  - Violation-Images/samut-prakan-thailand-oct-10-2019-a-woman-carries-small-children-on-a-scooter-in-the-city-family-trip-on-motorcycle-2AHFE2K_jpg.rf.4ea0a062aaf2e26264aed3f028f99973.jpg (Last modified: 2024-06-06 14:15:04+00:00, Size: 68047 bytes)
#  - Violation-Images/samut-prakan-thailand-oct-11-2022-a-people-in-a-raincoat-is-riding-a-motorbike-on-a-wet-road-2K9JKH1_jpg.rf.91e8c722966cbef65abd760c615c531c.jpg (Last modified: 2024-06-06 14:15:05+00:00, Size: 64200 bytes)
#  - Violation-Images/samut-prakan-thailand-sep-23-2022-a-parents-ride-a-motorcycle-with-a-small-son-2KFNRWH_jpg.rf.434cf3b60768d1db1bff3368418771a4.jpg (Last modified: 2024-06-06 14:15:05+00:00, Size: 53035 bytes)
#  - Violation-Images/v1.jpg (Last modified: 2024-06-06 17:55:55+00:00, Size: 44190 bytes)
#  - Violation-Images/v10.jpg (Last modified: 2024-06-06 17:55:55+00:00, Size: 320086 bytes)
#  - Violation-Images/v2.jpeg (Last modified: 2024-06-06 17:55:55+00:00, Size: 8322 bytes)
#  - Violation-Images/v3.jpg (Last modified: 2024-06-06 17:55:55+00:00, Size: 16198 bytes)
#  - Violation-Images/v4.jpg (Last modified: 2024-06-06 17:55:55+00:00, Size: 13094 bytes)
#  - Violation-Images/v5.jpg (Last modified: 2024-06-06 17:55:55+00:00, Size: 164826 bytes)
#  - Violation-Images/v6.jpg (Last modified: 2024-06-06 17:55:55+00:00, Size: 221472 bytes)
#  - Violation-Images/v7.jpeg (Last modified: 2024-06-06 17:55:55+00:00, Size: 62027 bytes)
#  - Violation-Images/v8.jpg (Last modified: 2024-06-06 17:55:55+00:00, Size: 65493 bytes)
#  - Violation-Images/v9.jpg (Last modified: 2024-06-06 17:55:55+00:00, Size: 71344 bytes)

# %% [markdown]
# **Uplaod Files to S3 Bucket**

# %%
import os
import boto3
from botocore.exceptions import NoCredentialsError, PartialCredentialsError

def upload_file_to_s3(file_path, bucket_name, folder_name, object_name=None):
    """
    Upload a file to an S3 bucket
    
    :param file_path: Path of the file to upload
    :param bucket_name: Bucket to upload to
    :param folder_name: Folder in the bucket to upload the file
    :param object_name: S3 object name. If not specified then file_path is used
    :return: True if file was uploaded, else False
    """
    if object_name is None:
        object_name = f"{folder_name}/{os.path.basename(file_path)}"

    # Upload the file
    s3_client = boto3.client('s3')
    try:
        s3_client.upload_file(file_path, bucket_name, object_name)
        print(f'{file_path} uploaded to {bucket_name}/{object_name}.')
        return True
    except NoCredentialsError:
        print('Credentials not available.')
        return False
    except PartialCredentialsError:
        print('Incomplete credentials provided.')
        return False
    except Exception as e:
        print(f'An error occurred: {e}')
        return False

def upload_files_from_folder(local_folder, bucket_name, s3_folder_name):
    """
    Upload all files from a local folder to an S3 bucket folder

    :param local_folder: Path to the local folder containing files to upload
    :param bucket_name: S3 bucket name
    :param s3_folder_name: S3 folder name (key prefix)
    """
    for root, _, files in os.walk(local_folder):
        for file_name in files:
            file_path = os.path.join(root, file_name)
            upload_file_to_s3(file_path, bucket_name, s3_folder_name)
        print(f'All files in {local_folder} uploaded to {bucket_name}/{s3_folder_name}.')


# Local folders
local_violation_folder = 'loction'
local_nonviolation_folder = 'loction'

# Upload violation images
upload_files_from_folder(local_violation_folder, bucket_name, violation_folder)

# Upload non-violation images
upload_files_from_folder(local_nonviolation_folder, bucket_name, nonviolation_folder)
# Out:
# C:/Users/Arshia Shaikh/local_violation_folder\1.jpeg uploaded to bikewatch/Violation-Images/1.jpeg.
# C:/Users/Arshia Shaikh/local_violation_folder\10.jpg uploaded to bikewatch/Violation-Images/10.jpg.
# C:/Users/Arshia Shaikh/local_violation_folder\2.jpg uploaded to bikewatch/Violation-Images/2.jpg.
# C:/Users/Arshia Shaikh/local_violation_folder\3.jpeg uploaded to bikewatch/Violation-Images/3.jpeg.
# C:/Users/Arshia Shaikh/local_violation_folder\4.jpg uploaded to bikewatch/Violation-Images/4.jpg.
# C:/Users/Arshia Shaikh/local_violation_folder\5.jpg uploaded to bikewatch/Violation-Images/5.jpg.
# C:/Users/Arshia Shaikh/local_violation_folder\6.jpg uploaded to bikewatch/Violation-Images/6.jpg.
# C:/Users/Arshia Shaikh/local_violation_folder\7.jpeg uploaded to bikewatch/Violation-Images/7.jpeg.
# C:/Users/Arshia Shaikh/local_violation_folder\8.jpg uploaded to bikewatch/Violation-Images/8.jpg.
# C:/Users/Arshia Shaikh/local_violation_folder\9.jpg uploaded to bikewatch/Violation-Images/9.jpg.
# All files in C:/Users/Arshia Shaikh/local_violation_folder uploaded to bikewatch/Violation-Images.
# C:/Users/Arshia Shaikh/local_nonviolation_folder\1.png uploaded to bikewatch/Nonviolation-Images/1.png.
# C:/Users/Arshia Shaikh/local_nonviolation_folder\10.jpg uploaded to bikewatch/Nonviolation-Images/10.jpg.
# C:/Users/Arshia Shaikh/local_nonviolation_folder\2.jpg uploaded to bikewatch/Nonviolation-Images/2.jpg.
# C:/Users/Arshia Shaikh/local_nonviolation_folder\3.jpg uploaded to bikewatch/Nonviolation-Images/3.jpg.
# C:/Users/Arshia Shaikh/local_nonviolation_folder\4.jpg uploaded to bikewatch/Nonviolation-Images/4.jpg.
# C:/Users/Arshia Shaikh/local_nonviolation_folder\5.png uploaded to bikewatch/Nonviolation-Images/5.png.
# C:/Users/Arshia Shaikh/local_nonviolation_folder\6.png uploaded to bikewatch/Nonviolation-Images/6.png.
# C:/Users/Arshia Shaikh/local_nonviolation_folder\7.png uploaded to bikewatch/Nonviolation-Images/7.png.
# C:/Users/Arshia Shaikh/local_nonviolation_folder\8.jpg uploaded to bikewatch/Nonviolation-Images/8.jpg.
# C:/Users/Arshia Shaikh/local_nonviolation_folder\9.jpg uploaded to bikewatch/Nonviolation-Images/9.jpg.
# All files in C:/Users/Arshia Shaikh/local_nonviolation_folder uploaded to bikewatch/Nonviolation-Images.
